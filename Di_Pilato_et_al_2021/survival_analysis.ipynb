# %% [markdown]
# # Survival analysis

# %% [markdown]
# In this notebook we examine whether CXCR6 expression predicts survival in human cancer patients using bulk RNA-Seq data sets publically available from the TCGA pan-cancer dataset: https://gdc.cancer.gov/about-data/publications/pancanatlas. Fig. 7 & S7 were generated using the code in this notebook.

# %%
import os, sys
import pandas as pd
import numpy as np

from scipy.stats import spearmanr
from scipy.stats import f_oneway
from scipy import stats
from scipy.stats import zscore
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from collections import Counter

from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test, multivariate_logrank_test
from lifelines.plotting import add_at_risk_counts
from lifelines import CoxPHFitter
from lifelines import CoxTimeVaryingFitter

import mm_functions_14_10_2020 as mm

import itertools
import functools
from collections import defaultdict

# %%
# Set figure parameters 
mylines = 0.15*2.82 # the number 2.82 is the difference
					# between Illustrator 1 pt and python 1 pt.
mpl.rcParams['axes.linewidth'] = mylines # default 1
mpl.rcParams['ytick.direction'] = 'out' # default 'in'
mpl.rcParams['xtick.direction'] = 'out' # default 'in'
mpl.rcParams['xtick.major.size'] = 2 # default 4
mpl.rcParams['ytick.major.size'] = 2 # default 4
mpl.rcParams['xtick.major.width'] = mylines # default 0.5
mpl.rcParams['ytick.major.width'] = mylines # default 0.5
mpl.rcParams['grid.linewidth'] = mylines/1.5 # default 0.5
mpl.rcParams['grid.color'] = '0.8' # default 'k'
mpl.rcParams['grid.linestyle'] = 'solid'# default ':'
mpl.rcParams['legend.frameon'] = False # default True
mpl.rcParams['figure.dpi']= 300
mpl.rc("savefig", dpi=300)
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
plt.rc('font', family = 'Arial',size = 12)

# %% [markdown]
# ## Survival functions

# %%
def fit_cph(end1_name = '', end1_time = None, end1_event = None, 
            end2_name = '', end2_time = None, end2_event = None,
            advice = False, strata = [], drop = [], **kwargs):
    
    # Define the keyword variables (function currently accepts up to 10 keyword variables):
    var1 = kwargs.get('var1', pd.DataFrame())
    var2 = kwargs.get('var2', pd.DataFrame())
    var3 = kwargs.get('var3', pd.DataFrame())
    var4 = kwargs.get('var4', pd.DataFrame())
    var5 = kwargs.get('var5', pd.DataFrame())
    var6 = kwargs.get('var6', pd.DataFrame())
    var7 = kwargs.get('var7', pd.DataFrame())
    var8 = kwargs.get('var8', pd.DataFrame())
    var9 = kwargs.get('var9', pd.DataFrame())
    var10 = kwargs.get('var10', pd.DataFrame())

    var1_name = kwargs.get('var1_name', str)
    var2_name = kwargs.get('var2_name', str)
    var3_name = kwargs.get('var3_name', str)
    var4_name = kwargs.get('var4_name', str)
    var5_name = kwargs.get('var5_name', str)
    var6_name = kwargs.get('var6_name', str)
    var7_name = kwargs.get('var7_name', str)
    var8_name = kwargs.get('var8_name', str)
    var9_name = kwargs.get('var9_name', str)
    var10_name = kwargs.get('var10_name', str)
    
    dummy_var1 = kwargs.get('dummy_var1', pd.DataFrame())
    dummy_var2 = kwargs.get('dummy_var2', pd.DataFrame())
    dummy_var3 = kwargs.get('dummy_var3', pd.DataFrame())
    dummy_var4 = kwargs.get('dummy_var4', pd.DataFrame())
    dummy_var5 = kwargs.get('dummy_var5', pd.DataFrame())
    
    dummy_var1_name = kwargs.get('dummy_var1_name', tuple())
    dummy_var2_name = kwargs.get('dummy_var2_name', tuple())
    dummy_var3_name = kwargs.get('dummy_var3_name', tuple())
    dummy_var4_name = kwargs.get('dummy_var4_name', tuple())
    dummy_var5_name = kwargs.get('dummy_var5_name', tuple())
    
    # Create a end_times/event dictionary: 
    end_times_dict = {end1_name : end1_time, 
                      end2_name : end2_time}
    
    end_events_dict = {end1_name : end1_event, 
                       end2_name : end2_event}
    
    # Create a variables dictionary: 
    variables = [kwargs[keyword] for keyword in kwargs.keys() if not keyword.endswith('name') if keyword.startswith('var')]
    variables_keys = [kwargs[keyword] for keyword in kwargs.keys() if keyword.endswith('name') if keyword.startswith('var')]
    variables_dict = dict(zip(variables_keys, variables)) 
  
    # Create a dummy variables dictionary: 
    dummy_variables = [kwargs[keyword] for keyword in kwargs.keys() if not keyword.endswith('name') if keyword.startswith('dummy')]
    dummy_variables_keys = [kwargs[keyword][0] for keyword in kwargs.keys() if keyword.endswith('name') if keyword.startswith('dummy')]
    dummy_variables_dict = dict(zip(dummy_variables_keys, dummy_variables))

    # Create a dummy ref dictionary: 
    dummy_ref = [kwargs[keyword][1] for keyword in kwargs.keys() if keyword.endswith('name') if keyword.startswith('dummy')]
    dummy_ref_keys = [kwargs[keyword][0] for keyword in kwargs.keys() if keyword.endswith('name') if keyword.startswith('dummy')]
    dummy_ref_dict = dict(zip(dummy_ref_keys, dummy_ref))
    
    # Add dummy variables to variables_dict: 
    dummy_columns = {}
    na = defaultdict(dict)
    for var in dummy_variables_dict.keys(): 
        
        if var not in strata: 
            
            # Safe number of NaN for each dummy variable:
            for end in [end1_name, end2_name]:
                if end:
                    na[end][var] = dummy_variables_dict[var].isna().sum()
        
            # Dropna : 
            dummy_variables_dict[var] = dummy_variables_dict[var].dropna()
        
            # Create dummies and drop ref variable: 
            temporary_df = pd.get_dummies(dummy_variables_dict[var]).drop(dummy_ref_dict[var], axis = 1)
        
            # Also initialize a list for dummy variable name storing: 
            dummy_columns[var] = list()

            for column in temporary_df.columns: 
                variables_dict[column] = temporary_df[column]
            
                # Also store dummy variable names: 
                dummy_columns[var].append(column)
        
        else:       
            variables_dict[var] = dummy_variables_dict[var]
            
            
    cph_dict = defaultdict(dict)
    # For each end, fit a cph model:
    for end in [end1_name, end2_name]: 
        if end: 
            print('Fitting:', end, '...')
        
            # For each variable, store non-NaN index values: 
            ix = {}
            for var in variables_dict.keys():
                
                ix[var] = variables_dict[var].dropna().index.values
                
                # For each patient, also store number of NaN for plotting: 
                na[end][var] = variables_dict[var].isna().sum()
            
            # Reduce dictionary of non-NaN index values to the intersecting set of all variables:  
            ix = functools.reduce(np.intersect1d, [ix[var] for var in ix.keys()])
            
            # For both end_time and end_event, store number of NaN values under ix: 
            na[end]['time'] = end_times_dict[end].loc[ix].isna().sum()
            na[end]['event'] = end_events_dict[end].loc[ix].isna().sum()
            
            # Intersect the intersecting non-NaN index of all variables with non-NaN index of end_time and end_event: 
            ix = end_times_dict[end].loc[ix].dropna().index.values
            ix = end_events_dict[end].loc[ix].dropna().index.values
            
            # For each end, store number of patients in the final intersecting ix (i.e. n): 
            n = len(ix)
            
            # For each end, store the number of events considering only patients in ix (i.e. the number of events): 
            events = end_events_dict[end].loc[ix].sum()
            print('Number of events:', events)
            
            # Create a cph_test pd.DataFrame (columns = unique variables and rows = patients): 
            end_times_dict[end].columns = [end + '_time']
            end_events_dict[end].columns = [end + '_event']
            cph_test = pd.concat([end_times_dict[end].loc[ix], end_events_dict[end].loc[ix]], axis = 1, join = 'inner', keys = [end + '_time', end + '_event'])
            
            # Join variables to pd.DataFrame() on intersecting non-NaN index: 
            for var in variables_dict.keys():
            
                variables_dict[var].name = var
                cph_test = pd.concat([cph_test, variables_dict[var].loc[ix]], axis = 1, join = 'inner') 
        
            # Check whether concatenation worked: 
            if not (cph_test.index.values == ix).all(): 
                raise Exception('Concatenated cph_test pd.DataFrame index does not match intersecting set ix')
            
            if not pd.Series(variables_keys).isin(cph_test.columns).all(): # this one should be the other way around but I leave it for now because it captures when a variable is not a pd.Series
                raise Exception('Concatenated cph_test pd.DataFrame does not contain all variables as columns')

         
            cph = CoxPHFitter()
            
            if strata:
                cph.fit(cph_test, duration_col= end + '_time', event_col= end + '_event', step_size = 0.25, strata = strata)
            
            else:
                cph.fit(cph_test, duration_col= end + '_time', event_col= end + '_event', step_size = 0.25)
                
       
            # Check the assumptions of the cph model: 
            cph.check_assumptions(cph_test, advice = advice, show_plots = advice)
            print('Concordance index:', round(cph.concordance_index_, 3))
            
            if cph.concordance_index_ < 0.5: 
                'Concordance is lower than the expected result from random predictions!'
            
            # Store cph.summary in variable cph_summary for the following operations: 
            cph_summary = cph.summary 
            
            # Change empty dummy variable NaN values from 0 into '': 
            for var in dummy_columns.keys():
                
                for key in dummy_columns[var]:
                    na[end][key] = '' # Don't delete the value as the empty string is needed to plot nothing instead of NaN 
  
                # Add dummy ref levels to cph.summary: 
                where = np.where(cph_summary.index == dummy_columns[var][0])[0][0]
                cph_summary = pd.concat([cph_summary.iloc[:where, :], pd.DataFrame({}, index = [var]), cph_summary.iloc[where:, :]])
            
            # Add stored NaN numbers to cph_summary: 
            na_concat = pd.DataFrame(pd.Series(na[end]), columns = ['number of NaN'])
            cph_summary = cph_summary.join(na_concat, how = 'left')
            
            if drop:
                cph_summary = cph_summary.drop(drop, axis = 0)
            
            # Store results in end_results_dict:
            cph_dict[end]['cph'] = cph_summary # cph fit result 
            cph_dict[end]['n'] = n # int = number of non-NaN (i.e. complete) patients
            cph_dict[end]['events'] = events 
            cph_dict[end]['na'] = na[end] # dict with keys = variable or time/event and values = number of NaN
            cph_dict[end]['ix'] = ix
            
            print('Finished fitting: ' + end + '!\n')
        
    return cph_dict

# %%
def plot_forest_cph(cph_summary, sort_on_pvalues = False, title = '', xlabel = '', fig_adjust = (5, 1), save = '', show = False, nan_str = True):
    
    cph_summary.index = cph_summary.index.astype(str)
    cph_summary = cph_summary.iloc[::-1]
    indexLen = np.array([len(index) for index in cph_summary.index]).max()

    a, fig, gs = mm.startfig(indexLen + cph_summary['exp(coef) upper 95%'].max() + fig_adjust[0], fig_adjust[1]*len(cph_summary['-log2(p)']))
    
    if sort_on_pvalues:
        cph_summary = cph_summary.sort_values('-log2(p)')
    
    ylabels_first = []
    ylabels_second = []

    for hazard, y, state, hazard_lower, hazard_upper, pvalue, nnan, color in zip(np.log10(cph_summary['exp(coef)']), 
                                                                                 range(0, len(cph_summary['p'])), 
                                                                                 cph_summary.index, 
                                                                                 np.log10(cph_summary['exp(coef) lower 95%']), 
                                                                                 np.log10(cph_summary['exp(coef) upper 95%']),
                                                                                 cph_summary['p'], 
                                                                                 cph_summary['number of NaN'], 
                                                                                 itertools.cycle(['lightgrey', 'white'])):
        
        if pvalue < 0.05: 
            a.scatter(hazard, y, s = 25, c = 'black', zorder = 4, marker = 's')
            a.plot([hazard_lower, hazard_upper], [y, y], c = 'black', lw = 1, zorder = 2)
        
        else:
            a.scatter(hazard, y, s = 25, c = 'grey', zorder = 4, marker = 's')
            a.plot([hazard_lower, hazard_upper], [y, y], c = 'grey', lw = 1, zorder = 2)
    
        # 10**hazard + 95% CI str 
        if np.isnan(pvalue):
            
            if nan_str: 
                hazard_str = str(nnan)
            
            else: 
                hazard_str = ''
        
        else:
            
            if nan_str:
                hazard_str = '{:.2f}'.format(round(10**hazard, 2)) + ' (' + '{:.2f}'.format(round(10**hazard_lower, 2)) + '-' + '{:.2f}'.format(round(10**hazard_upper,2)) + ') ' + '    {:.2f}'.format(round(np.log10(pvalue),2)) + ' ' + str(nnan)
                
            else:
                hazard_str = '{:.2f}'.format(round(10**hazard, 2)) + ' (' + '{:.2f}'.format(round(10**hazard_lower, 2)) + '-' + '{:.2f}'.format(round(10**hazard_upper,2)) + ') ' + '    {:.2f}'.format(round(np.log10(pvalue),2))
                
        ylabels_first.append(state)
        ylabels_second.append(hazard_str)

        a.axhspan(y - 0.5, y + 0.5, facecolor = color, clip_on = False, zorder = -2)
        #a.add_patch(patches.Rectangle((-indexLen/31, y-0.5), abs(-indexLen/31) + cph_summary['exp(coef) upper 95%'].max(), 1, alpha=1, facecolor = color, zorder = -2, clip_on=False))
            
    a.axvline(np.log10(1), zorder = 0, lw = 1, c = 'grey')
            
    # set yticks
    a.set_yticks(range(0, len(cph_summary['-log2(p)'])))
    a.set_yticklabels(ylabels_first)

    secay = a.secondary_yaxis('right')
    secay.set_yticks(range(0, len(cph_summary['-log2(p)'])))
    secay.set_yticklabels(ylabels_second)
        
    a.tick_params(axis=u'both', which=u'both',length=0)
    secay.tick_params(axis=u'both', which=u'both',length=0)

    # set spines
    a.spines['left'].set_visible(False)
    a.spines['right'].set_color('white') # matplotlib secondary yaxis bug: I can't make the right spine invisible anymore
    a.spines['top'].set_visible(False)

    # set title and xaxis label
    a.set_title(title)
    a.set_xlabel(xlabel)

    a.set_ylim(-0.5, len(cph_summary['-log2(p)'])-0.5)
    plt.tight_layout()
    plt.savefig(save, dpi = 400)
    
    if show == True: 
        plt.show()
    
    plt.close()

# %% [markdown]
# ## Load TCGA data

# %%
# TCGA sample info from PANCAN atlas: https://gdc.cancer.gov/about-data/publications/pancanatlas
TCGA_sample_info = pd.read_excel('./data/tcga/TCGA-CDR-SupplementalTableS1.xlsx', sheet_name=0, header=0, index_col=1)
TCGA_survival = pd.read_excel('./data/tcga/TCGA-CDR-SupplementalTableS1.xlsx', sheet_name=2, header=0, index_col=1)

# %%
TCGA_sample_info['ajcc_pathologic_tumor_stage'].unique()
# Out:
# array(['Stage II', 'Stage IV', 'Stage III', '[Not Available]', 'Stage I',
#        'Stage X', 'Stage IIB', 'Stage IA', 'Stage IIIA', 'Stage IIA',
#        'Stage IIIC', 'Stage IB', 'Stage IIIB', '[Discrepancy]',
#        'Stage IVB', 'Stage IVA', 'Stage IIC', '[Not Applicable]',
#        '[Unknown]', 'Stage IVC', 'I/II NOS', 'Stage 0', 'IS'],
#       dtype=object)

# %%
stages_map = {
    'Stage 0': 'Stage 0 & I', # Merge stage 0 and I 
    'Stage I': 'Stage 0 & I', 
    'Stage IA': 'Stage 0 & I', 
    'Stage IB': 'Stage 0 & I', 
    'I/II NOS': np.nan, # Ambigious 
    'Stage II': 'Stage II',
    'Stage IIA': 'Stage II', 
    'Stage IIB': 'Stage II', 
    'Stage IIC': 'Stage II', 
    'Stage III': 'Stage III', 
    'Stage IIIA': 'Stage III', 
    'Stage IIIB': 'Stage III', 
    'Stage IIIC': 'Stage III', 
    'Stage IV': 'Stage IV',
    'Stage IVA': 'Stage IV', 
    'Stage IVB': 'Stage IV', 
    'Stage IVC': 'Stage IV', 
    'Stage X': np.nan, 
    '[Not Available]': np.nan, 
    '[Not Applicable]': np.nan,
    '[Discrepancy]': np.nan,
    'IS': np.nan, 
    '[Unknown]': np.nan 
}

gender_map = {
    'MALE': 0, 
    'FEMALE': 1 
}

# %%
TCGA_sample_info['tumor_stage'] = TCGA_sample_info['ajcc_pathologic_tumor_stage'].map(stages_map)
TCGA_sample_info['sex'] = TCGA_sample_info['gender'].map(gender_map)

# %%
# Load SKCM additional sample info
SKCM_info = pd.read_excel('/Users/mariusmessemaker/Documents/Project/mempel/data/tcga/SKCM.xlsx', sheet_name = 3, header = 1, index_col = 0)
SKCM_info.index = SKCM_info.index.str[0:12]
print(SKCM_info.shape)
SKCM_info = SKCM_info.iloc[~SKCM_info.index.duplicated(), :]
print(SKCM_info.shape)

regional_vs_primary_SKCM_map = {
    '-' : np.nan, 
    'Primary_Disease' : 'Primary_Disease', 
    'Regional_Lymph_Node' : 'Regional_Lymph_Node', 
    'Regional_Skin_or_Soft_Tissue' : 'Regional_Skin_or_Soft_Tissue', 
    'Distant_Metastases': 'Distant_Metastases'
}

print(SKCM_info['REGIONAL_VS_PRIMARY'].value_counts())
SKCM_info['REGIONAL_VS_PRIMARY'] = SKCM_info['REGIONAL_VS_PRIMARY'].map(regional_vs_primary_SKCM_map)
print(SKCM_info['REGIONAL_VS_PRIMARY'].value_counts())
print(SKCM_info['REGIONAL_VS_PRIMARY'].unique())
# Out:
# (333, 111)
# (331, 111)
# Regional_Lymph_Node             160
# Regional_Skin_or_Soft_Tissue     52
# -                                43
# Primary_Disease                  41
# Distant_Metastases               35
# Name: REGIONAL_VS_PRIMARY, dtype: int64
# Regional_Lymph_Node             160
# Regional_Skin_or_Soft_Tissue     52
# Primary_Disease                  41
# Distant_Metastases               35
# Name: REGIONAL_VS_PRIMARY, dtype: int64
# [nan 'Primary_Disease' 'Regional_Lymph_Node'
#  'Regional_Skin_or_Soft_Tissue' 'Distant_Metastases']

# %%
# TCGA pancan expression data
# gene expression from pancan atlas: https://gdc.cancer.gov/about-data/publications/pancanatlas
TCGA_pancan_exp = pd.read_csv('./data/tcga/EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv', sep='\t', header=0, index_col=0)

# sample codes from code table https://gdc.cancer.gov/resources-tcga-users/tcga-code-tables/sample-type-codes
tumor_codes = ['01', '02', '05', '06'] # 06 is also metastatic sites 
normal_codes = ['10', '11', '12', '13', '14']

# divide samples into tumors and normals
stype = ['tumor' if x.split('-')[3][0:2] in tumor_codes else 'normal' if x.split('-')[3][0:2] in normal_codes else 'NA' for x in TCGA_pancan_exp.columns.values]

sample_type = pd.Series(stype, index = TCGA_pancan_exp.columns.values)

#change index to gene names only
TCGA_pancan_exp.index = map(lambda x: x.split('|')[0], TCGA_pancan_exp.index.values)

# extract tumors only
tumor_exp = TCGA_pancan_exp[sample_type[sample_type=='tumor'].index.values]

# extract normal samples only
normal_exp = TCGA_pancan_exp[sample_type[sample_type=='normal'].index.values]

# shorten column names/patient IDs
tumor_exp.rename(columns = lambda x: x[0:12], inplace=True)
normal_exp.rename(columns = lambda x: x[0:12], inplace=True)

# remove duplicate gene expression data for the same sample
tumor_exp_unique = tumor_exp.iloc[:, ~tumor_exp.columns.duplicated()].T
normal_exp_unique = normal_exp.iloc[:, ~normal_exp.columns.duplicated()].T
# Out:
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/pandas/core/frame.py:4304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Transform expression matrix to dense ranking for DC gene scoring 
tumor_dense_rank_unique = tumor_exp_unique.transform('rank', method = 'dense', axis = 0)

# %% [markdown]
# ## Score genes

# %%
state_genes = {
'CD8B': ['CD8B'],
'CCR1': ['CCR1'],
'CCR10': ['CCR10'], 
'CCR2': ['CCR2'], 
'CCR3': ['CCR3'], 
'CCR4': ['CCR4'], 
'CCR5': ['CCR5'], 
'CCR6':['CCR6'], 
'CCR7':['CCR7'], 
'CCR8':['CCR8'], 
'CCR9':['CCR9'], 
'CX3CR1':['CX3CR1'],
'CXCR1':['CXCR1'], 
'CXCR2':['CXCR2'],
'CXCR3':['CXCR3'],
'CXCR4':['CXCR4'],
'CXCR5':['CXCR5'],
'CXCR6':['CXCR6'], 
'CXCR7':['CXCR7'],  
'XCR1':['XCR1'],
'CD19':['CD19'],
'CD4':['CD4'],
'CXCL16':['CXCL16'],
'IL12B':['IL12B'],
'NK cells':['NCR1', 'SH2D1B']}

# %%
cancers = ['BRCA', 'HNSC', 'LUAD', 'LUSC', 'STAD', 'KIRC', 'BLCA', 'LIHC', 'SKCM']

# %%
log_zscore = True

state_scores = defaultdict(dict)
for cancer in cancers:
    print(cancer)
    os.mkdir('./outputs/survival/' + cancer)
    os.mkdir('./outputs/survival/' + cancer + '/distribution/')
    
    # Exclude samples that are metastatic (or lymph-node metastatic in SKCM)
    #if cancer in exclude_dict.keys():
     #   ix0 = TCGA_sample_info[~TCGA_sample_info.index.isin(exclude_dict[cancer])].index.values        
      #  ix1 = TCGA_sample_info[TCGA_sample_info['type']==cancer].index.values 
       #  ix = np.intersect1d(ix0, ix1)
    
    #elif cancer == 'SKCM': 
     #   ix = SKCM_info[~SKCM_info.index.isin(SKCM_ix)].index.values 
        
    ix = TCGA_sample_info[TCGA_sample_info['type']==cancer].index.values
    
    # Check whether indexing worked: 
    print(TCGA_sample_info.loc[ix]['type'].unique(), 'n=', len([sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index]))
    
    for state in state_genes.keys():
        print('Started scoring:', state, '...')
        
        # Check whether genes are detected 
        genes_first = [gene for gene in state_genes[state] if gene in tumor_exp_unique.columns]
        genes = []
        
        for gene in genes_first:
            
            # Check whether genes are NaN although they are detected 
            if tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index], gene].isna().sum() < 1:
                genes.append(gene)
                
            else:
                # If a gene is not included in the columns or NaN: 
                print('Not detected:', gene)
        
        # Plot distribution before gene scoring 
        sns.displot(tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index], genes].mean(1))
        plt.title('Distribution ' + state + ' before scoring')
        plt.savefig('./outputs/survival/' + cancer + '/distribution/' + state + '_before.pdf', dpi = 300)
        plt.close()
        
        # Score genes 
        if log_zscore:
            # EdgeR pseudo count calculation https://bioinformatics.stackexchange.com/questions/4985/how-is-prior-count-used-by-edgers-cpm
            pseudo = (tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index]].sum(1)/tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index]].sum(1).mean())*2*0.25
            
            if not (pseudo.index == tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index]].index).all():
                raise Exception('pseudo index not the same as expression matrix index')
            
            if len(genes) <= 1:
                state_scores[cancer][state] = np.log2(tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index], 
                                                        genes].add(pseudo, axis = 0)).apply(zscore, axis = 0)[genes[0]]
            else:
                state_scores[cancer][state] = np.log2(tumor_exp_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_exp_unique.index], 
                                                      genes].add(pseudo, axis = 0)).apply(zscore, axis = 0).mean(1)
                                            
        else: 
            state_scores[cancer][state] = tumor_dense_rank_unique.loc[[sample for sample in TCGA_sample_info.loc[ix].index.values if sample in tumor_dense_rank_unique.index], 
                                                                       genes].sum(1)/len(genes)
            state_scores[cancer][state] = state_scores[cancer][state]/state_scores[cancer][state].max()
            
        print(len(state_scores[cancer][state]))
        
        # Plot distribution of scored genes 
        sns.displot(state_scores[cancer][state])
        plt.title('Distribution ' + state + ' after scoring')
        plt.savefig('./outputs/survival/' + cancer + '/distribution/' + state + '_after.pdf', dpi = 300)
        plt.close()
# Out:
# BRCA
# ['BRCA'] n= 1095
# Started scoring: CD8B ...
# 1095
# Started scoring: CCR1 ...
# 1095
# Started scoring: CCR10 ...
# 1095
# Started scoring: CCR2 ...
# 1095
# Started scoring: CCR3 ...
# 1095
# Started scoring: CCR4 ...
# 1095
# Started scoring: CCR5 ...
# 1095
# Started scoring: CCR6 ...
# 1095
# Started scoring: CCR7 ...
# 1095
# Started scoring: CCR8 ...
# 1095
# Started scoring: CCR9 ...
# 1095
# Started scoring: CX3CR1 ...
# 1095
# Started scoring: CXCR1 ...
# 1095
# Started scoring: CXCR2 ...
# 1095
# Started scoring: CXCR3 ...
# 1095
# Started scoring: CXCR4 ...
# 1095
# Started scoring: CXCR5 ...
# 1095
# Started scoring: CXCR6 ...
# 1095
# Started scoring: CXCR7 ...
# 1095
# Started scoring: XCR1 ...
# 1095
# Started scoring: CD19 ...
# 1095
# Started scoring: CD4 ...
# 1095
# Started scoring: CXCL16 ...
# 1095
# Started scoring: IL12B ...
# 1095
# Started scoring: NK cells ...
# 1095
# HNSC
# ['HNSC'] n= 520
# Started scoring: CD8B ...
# 520
# Started scoring: CCR1 ...
# 520
# Started scoring: CCR10 ...
# 520
# Started scoring: CCR2 ...
# 520
# Started scoring: CCR3 ...
# 520
# Started scoring: CCR4 ...
# 520
# Started scoring: CCR5 ...
# 520
# Started scoring: CCR6 ...
# 520
# Started scoring: CCR7 ...
# 520
# Started scoring: CCR8 ...
# 520
# Started scoring: CCR9 ...
# 520
# Started scoring: CX3CR1 ...
# 520
# Started scoring: CXCR1 ...
# 520
# Started scoring: CXCR2 ...
# 520
# Started scoring: CXCR3 ...
# 520
# Started scoring: CXCR4 ...
# 520
# Started scoring: CXCR5 ...
# 520
# Started scoring: CXCR6 ...
# 520
# Started scoring: CXCR7 ...
# 520
# Started scoring: XCR1 ...
# 520
# Started scoring: CD19 ...
# 520
# Started scoring: CD4 ...
# 520
# Started scoring: CXCL16 ...
# 520
# Started scoring: IL12B ...
# 520
# Started scoring: NK cells ...
# 520
# LUAD
# ['LUAD'] n= 515
# Started scoring: CD8B ...
# 515
# Started scoring: CCR1 ...
# 515
# Started scoring: CCR10 ...
# 515
# Started scoring: CCR2 ...
# 515
# Started scoring: CCR3 ...
# 515
# Started scoring: CCR4 ...
# 515
# Started scoring: CCR5 ...
# 515
# Started scoring: CCR6 ...
# 515
# Started scoring: CCR7 ...
# 515
# Started scoring: CCR8 ...
# 515
# Started scoring: CCR9 ...
# 515
# Started scoring: CX3CR1 ...
# 515
# Started scoring: CXCR1 ...
# 515
# Started scoring: CXCR2 ...
# 515
# Started scoring: CXCR3 ...
# 515
# Started scoring: CXCR4 ...
# 515
# Started scoring: CXCR5 ...
# 515
# Started scoring: CXCR6 ...
# 515
# Started scoring: CXCR7 ...
# 515
# Started scoring: XCR1 ...
# 515
# Started scoring: CD19 ...
# 515
# Started scoring: CD4 ...
# 515
# Started scoring: CXCL16 ...
# 515
# Started scoring: IL12B ...
# 515
# Started scoring: NK cells ...
# 515
# LUSC
# ['LUSC'] n= 501
# Started scoring: CD8B ...
# 501
# Started scoring: CCR1 ...
# 501
# Started scoring: CCR10 ...
# 501
# Started scoring: CCR2 ...
# 501
# Started scoring: CCR3 ...
# 501
# Started scoring: CCR4 ...
# 501
# Started scoring: CCR5 ...
# 501
# Started scoring: CCR6 ...
# 501
# Started scoring: CCR7 ...
# 501
# Started scoring: CCR8 ...
# 501
# Started scoring: CCR9 ...
# 501
# Started scoring: CX3CR1 ...
# 501
# Started scoring: CXCR1 ...
# 501
# Started scoring: CXCR2 ...
# 501
# Started scoring: CXCR3 ...
# 501
# Started scoring: CXCR4 ...
# 501
# Started scoring: CXCR5 ...
# 501
# Started scoring: CXCR6 ...
# 501
# Started scoring: CXCR7 ...
# 501
# Started scoring: XCR1 ...
# 501
# Started scoring: CD19 ...
# 501
# Started scoring: CD4 ...
# 501
# Started scoring: CXCL16 ...
# 501
# Started scoring: IL12B ...
# 501
# Started scoring: NK cells ...
# 501
# STAD
# ['STAD'] n= 415
# Started scoring: CD8B ...
# 415
# Started scoring: CCR1 ...
# 415
# Started scoring: CCR10 ...
# 415
# Started scoring: CCR2 ...
# 415
# Started scoring: CCR3 ...
# 415
# Started scoring: CCR4 ...
# 415
# Started scoring: CCR5 ...
# 415
# Started scoring: CCR6 ...
# 415
# Started scoring: CCR7 ...
# 415
# Started scoring: CCR8 ...
# 415
# Started scoring: CCR9 ...
# 415
# Started scoring: CX3CR1 ...
# 415
# Started scoring: CXCR1 ...
# 415
# Started scoring: CXCR2 ...
# 415
# Started scoring: CXCR3 ...
# 415
# Started scoring: CXCR4 ...
# 415
# Started scoring: CXCR5 ...
# 415
# Started scoring: CXCR6 ...
# 415
# Started scoring: CXCR7 ...
# 415
# Started scoring: XCR1 ...
# 415
# Started scoring: CD19 ...
# 415
# Started scoring: CD4 ...
# 415
# Started scoring: CXCL16 ...
# 415
# Started scoring: IL12B ...
# 415
# Started scoring: NK cells ...
# 415
# KIRC
# ['KIRC'] n= 533
# Started scoring: CD8B ...
# 533
# Started scoring: CCR1 ...
# 533
# Started scoring: CCR10 ...
# 533
# Started scoring: CCR2 ...
# 533
# Started scoring: CCR3 ...
# 533
# Started scoring: CCR4 ...
# 533
# Started scoring: CCR5 ...
# 533
# Started scoring: CCR6 ...
# 533
# Started scoring: CCR7 ...
# 533
# Started scoring: CCR8 ...
# 533
# Started scoring: CCR9 ...
# 533
# Started scoring: CX3CR1 ...
# 533
# Started scoring: CXCR1 ...
# 533
# Started scoring: CXCR2 ...
# 533
# Started scoring: CXCR3 ...
# 533
# Started scoring: CXCR4 ...
# 533
# Started scoring: CXCR5 ...
# 533
# Started scoring: CXCR6 ...
# 533
# Started scoring: CXCR7 ...
# 533
# Started scoring: XCR1 ...
# 533
# Started scoring: CD19 ...
# 533
# Started scoring: CD4 ...
# 533
# Started scoring: CXCL16 ...
# 533
# Started scoring: IL12B ...
# 533
# Started scoring: NK cells ...
# 533
# BLCA
# ['BLCA'] n= 408
# Started scoring: CD8B ...
# 408
# Started scoring: CCR1 ...
# 408
# Started scoring: CCR10 ...
# 408
# Started scoring: CCR2 ...
# 408
# Started scoring: CCR3 ...
# 408
# Started scoring: CCR4 ...
# 408
# Started scoring: CCR5 ...
# 408
# Started scoring: CCR6 ...
# 408
# Started scoring: CCR7 ...
# 408
# Started scoring: CCR8 ...
# 408
# Started scoring: CCR9 ...
# 408
# Started scoring: CX3CR1 ...
# 408
# Started scoring: CXCR1 ...
# 408
# Started scoring: CXCR2 ...
# 408
# Started scoring: CXCR3 ...
# 408
# Started scoring: CXCR4 ...
# 408
# Started scoring: CXCR5 ...
# 408
# Started scoring: CXCR6 ...
# 408
# Started scoring: CXCR7 ...
# 408
# Started scoring: XCR1 ...
# 408
# Started scoring: CD19 ...
# 408
# Started scoring: CD4 ...
# 408
# Started scoring: CXCL16 ...
# 408
# Started scoring: IL12B ...
# 408
# Started scoring: NK cells ...
# 408
# LIHC
# ['LIHC'] n= 371
# Started scoring: CD8B ...
# 371
# Started scoring: CCR1 ...
# 371
# Started scoring: CCR10 ...
# 371
# Started scoring: CCR2 ...
# 371
# Started scoring: CCR3 ...
# 371
# Started scoring: CCR4 ...
# 371
# Started scoring: CCR5 ...
# 371
# Started scoring: CCR6 ...
# 371
# Started scoring: CCR7 ...
# 371
# Started scoring: CCR8 ...
# 371
# Started scoring: CCR9 ...
# 371
# Started scoring: CX3CR1 ...
# 371
# Started scoring: CXCR1 ...
# 371
# Started scoring: CXCR2 ...
# 371
# Started scoring: CXCR3 ...
# 371
# Started scoring: CXCR4 ...
# 371
# Started scoring: CXCR5 ...
# 371
# Started scoring: CXCR6 ...
# 371
# Started scoring: CXCR7 ...
# 371
# Started scoring: XCR1 ...
# 371
# Started scoring: CD19 ...
# 371
# Started scoring: CD4 ...
# 371
# Started scoring: CXCL16 ...
# 371
# Started scoring: IL12B ...
# 371
# Started scoring: NK cells ...
# 371
# SKCM
# ['SKCM'] n= 469
# Started scoring: CD8B ...
# 469
# Started scoring: CCR1 ...
# 469
# Started scoring: CCR10 ...
# 469
# Started scoring: CCR2 ...
# 469
# Started scoring: CCR3 ...
# 469
# Started scoring: CCR4 ...
# 469
# Started scoring: CCR5 ...
# 469
# Started scoring: CCR6 ...
# 469
# Started scoring: CCR7 ...
# 469
# Started scoring: CCR8 ...
# 469
# Started scoring: CCR9 ...
# 469
# Started scoring: CX3CR1 ...
# 469
# Started scoring: CXCR1 ...
# 469
# Started scoring: CXCR2 ...
# 469
# Started scoring: CXCR3 ...
# 469
# Started scoring: CXCR4 ...
# 469
# Started scoring: CXCR5 ...
# 469
# Started scoring: CXCR6 ...
# 469
# Started scoring: CXCR7 ...
# 469
# Started scoring: XCR1 ...
# 469
# Started scoring: CD19 ...
# 469
# Started scoring: CD4 ...
# 469
# Started scoring: CXCL16 ...
# 469
# Started scoring: IL12B ...
# 469
# Started scoring: NK cells ...
# 469

# %% [markdown]
# ## Continious association of scores

# %%
states = ['CD8B', 'CXCL16', 'CXCR6', 'CXCR3', 'CXCR2', 'CCR5', 'CCR10', 'CCR8', 'CD19', 'CD4', 'NK cells', 'IL12B']

# %%
for cancer in cancers: 
    print(cancer)
    os.mkdir('./outputs/survival/' + cancer + '/scatter/')
    
    # Compare all combinations: 
    for state1, state2 in itertools.combinations(states, 2):
        name = state1 + '_with_' + state2
        print('Comparing:', name)
        
        # Plot scatterplot that shows relation of the continious variables: 
        a, fig, gs = mm.startfig(8, 8) 
        
        if not (state_scores[cancer][state1].index == state_scores[cancer][state2].index).all():
            raise Excpetion('Indexes are not the same')
        
        a.scatter(state_scores[cancer][state1], state_scores[cancer][state2], c = 'black', s = 5)
        a.set_xlabel(state1 + ' score')
        a.set_ylabel(state2 + ' score')
        
        if spearmanr(state_scores[cancer][state1], state_scores[cancer][state2])[1] < 0.001:
            a.set_title(cancer + ' r='+str(round(spearmanr(state_scores[cancer][state1], state_scores[cancer][state2])[0],2)) + ' p < 0.001')
        else:
            a.set_title(cancer + ' r='+str(round(spearmanr(state_scores[cancer][state1], state_scores[cancer][state2])[0],2)) + ' p=' + str(round(spearmanr(state_scores[cancer][state1], state_scores[cancer][state2])[1],3)))
            
        plt.locator_params(nbins=10)
        plt.tight_layout()
        plt.savefig('./outputs/survival/' + cancer + '/scatter/' + name + '.pdf')
        plt.close()
# Out:
# BRCA
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# HNSC
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# LUAD
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# LUSC
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# STAD
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# KIRC
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# BLCA
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# LIHC
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B
# SKCM
# Comparing: CD8B_with_CXCL16
# Comparing: CD8B_with_CXCR6
# Comparing: CD8B_with_CXCR3
# Comparing: CD8B_with_CXCR2
# Comparing: CD8B_with_CCR5
# Comparing: CD8B_with_CCR10
# Comparing: CD8B_with_CCR8
# Comparing: CD8B_with_CD19
# Comparing: CD8B_with_CD4
# Comparing: CD8B_with_NK cells
# Comparing: CD8B_with_IL12B
# Comparing: CXCL16_with_CXCR6
# Comparing: CXCL16_with_CXCR3
# Comparing: CXCL16_with_CXCR2
# Comparing: CXCL16_with_CCR5
# Comparing: CXCL16_with_CCR10
# Comparing: CXCL16_with_CCR8
# Comparing: CXCL16_with_CD19
# Comparing: CXCL16_with_CD4
# Comparing: CXCL16_with_NK cells
# Comparing: CXCL16_with_IL12B
# Comparing: CXCR6_with_CXCR3
# Comparing: CXCR6_with_CXCR2
# Comparing: CXCR6_with_CCR5
# Comparing: CXCR6_with_CCR10
# Comparing: CXCR6_with_CCR8
# Comparing: CXCR6_with_CD19
# Comparing: CXCR6_with_CD4
# Comparing: CXCR6_with_NK cells
# Comparing: CXCR6_with_IL12B
# Comparing: CXCR3_with_CXCR2
# Comparing: CXCR3_with_CCR5
# Comparing: CXCR3_with_CCR10
# Comparing: CXCR3_with_CCR8
# Comparing: CXCR3_with_CD19
# Comparing: CXCR3_with_CD4
# Comparing: CXCR3_with_NK cells
# Comparing: CXCR3_with_IL12B
# Comparing: CXCR2_with_CCR5
# Comparing: CXCR2_with_CCR10
# Comparing: CXCR2_with_CCR8
# Comparing: CXCR2_with_CD19
# Comparing: CXCR2_with_CD4
# Comparing: CXCR2_with_NK cells
# Comparing: CXCR2_with_IL12B
# Comparing: CCR5_with_CCR10
# Comparing: CCR5_with_CCR8
# Comparing: CCR5_with_CD19
# Comparing: CCR5_with_CD4
# Comparing: CCR5_with_NK cells
# Comparing: CCR5_with_IL12B
# Comparing: CCR10_with_CCR8
# Comparing: CCR10_with_CD19
# Comparing: CCR10_with_CD4
# Comparing: CCR10_with_NK cells
# Comparing: CCR10_with_IL12B
# Comparing: CCR8_with_CD19
# Comparing: CCR8_with_CD4
# Comparing: CCR8_with_NK cells
# Comparing: CCR8_with_IL12B
# Comparing: CD19_with_CD4
# Comparing: CD19_with_NK cells
# Comparing: CD19_with_IL12B
# Comparing: CD4_with_NK cells
# Comparing: CD4_with_IL12B
# Comparing: NK cells_with_IL12B

# %% [markdown]
# ## Association of scores with tumor stage

# %%
states = ['CD8B', 'CXCL16', 'CXCR6', 'CXCR3', 'CXCR2', 'CCR5', 'CCR10', 'CD4', 'NK cells', 'IL12B']

# %%
for cancer in cancers: 
    print(cancer)
    os.mkdir('./outputs/survival/' + cancer + '/tumor_stage_boxplot/')
    
    for state in states: 
        print(state)

        score_stage_df = pd.DataFrame(state_scores[cancer][state], columns = [state]).join(TCGA_sample_info['tumor_stage']).dropna()

        kruskal = stats.kruskal(score_stage_df[score_stage_df['tumor_stage'] == 'Stage 0 & I'][state],
                              score_stage_df[score_stage_df['tumor_stage'] == 'Stage II'][state],
                              score_stage_df[score_stage_df['tumor_stage'] == 'Stage III'][state], 
                              score_stage_df[score_stage_df['tumor_stage'] == 'Stage IV'][state])
        
        if kruskal[1] < 0.05: 
            print('significant!')
        
        order = ['Stage 0 & I', 'Stage II', 'Stage III', 'Stage IV']
        ax = sns.swarmplot(x = 'tumor_stage', y = state, data = score_stage_df, color = 'black', zorder = 0, s = 3, order = order)
        ax = sns.boxplot(x = 'tumor_stage', y = state, data = score_stage_df, color = 'white', zorder = 4, order = order)
        
        ax.set_xticklabels(['Stage 0 & I (n=' + str(len(score_stage_df[score_stage_df['tumor_stage'] == 'Stage 0 & I'])) + ')',
                            'Stage II (n=' + str(len(score_stage_df[score_stage_df['tumor_stage'] == 'Stage II'])) + ')',
                            'Stage III (n=' + str(len(score_stage_df[score_stage_df['tumor_stage'] == 'Stage III'])) + ')',
                            'Stage IV (n=' + str(len(score_stage_df[score_stage_df['tumor_stage'] == 'Stage IV'])) + ')'])
        
        plt.xlabel('')
        
        if kruskal[1] < 0.001:
            ax.set_title(cancer + ' H=' + str(round(kruskal[0], 2)) + ' p < 0.001')
        else: 
            ax.set_title(cancer + ' H=' + str(round(kruskal[0], 2)) + ' p=' + str(round(kruskal[1], 2)))
            
        for patch in ax.artists:
            r, g, b, a = patch.get_facecolor()
            patch.set_facecolor((r, g, b, 0))
        
        plt.ylabel(state + ' score')
        plt.tight_layout()
        plt.savefig('./outputs/survival/' + cancer + '/' + 'tumor_stage_boxplot/' + state + '.pdf')
        plt.close()
# Out:
# BRCA
# CD8B
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# CXCL16
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# CXCR6
# CXCR3
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# CXCR2
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 19.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# CCR5
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 8.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# CCR10
# significant!
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# CD4
# NK cells
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# IL12B
# HNSC
# CD8B
# CXCL16
# CXCR6
# significant!
# CXCR3
# significant!
# CXCR2
# significant!
# CCR5
# significant!
# CCR10
# CD4
# NK cells
# significant!
# IL12B
# LUAD
# CD8B
# significant!
# CXCL16
# CXCR6
# significant!
# CXCR3
# CXCR2
# CCR5
# significant!
# CCR10
# significant!
# CD4
# significant!
# NK cells
# IL12B
# significant!
# LUSC
# CD8B
# CXCL16
# CXCR6
# CXCR3
# CXCR2
# CCR5
# CCR10
# CD4
# NK cells
# IL12B
# STAD
# CD8B
# CXCL16
# CXCR6
# CXCR3
# significant!
# CXCR2
# significant!
# CCR5
# significant!
# CCR10
# significant!
# CD4
# significant!
# NK cells
# IL12B
# KIRC
# CD8B
# significant!
# CXCL16
# CXCR6
# significant!
# CXCR3
# significant!
# CXCR2
# CCR5
# significant!
# CCR10
# CD4
# NK cells
# IL12B
# BLCA
# CD8B
# CXCL16
# CXCR6
# CXCR3
# CXCR2
# CCR5
# CCR10
# CD4
# NK cells
# IL12B
# LIHC
# CD8B
# CXCL16
# CXCR6
# CXCR3
# CXCR2
# CCR5
# CCR10
# CD4
# NK cells
# IL12B
# SKCM
# CD8B
# significant!
# CXCL16
# CXCR6
# significant!
# CXCR3
# significant!
# CXCR2
# CCR5
# significant!
# CCR10
# CD4
# significant!
# NK cells
# significant!
# IL12B

# %% [markdown]
# ## Association scores with lymphocyte score in SKCM

# %%
states = ['CD8B', 'CXCL16', 'CXCR6', 'CXCR3', 'CXCR2', 'CCR5', 'CCR10', 'CD4', 'NK cells', 'IL12B']

# %%
lymphocyte_score_map = {
    0: 'Lc score 0 & 2', 
    2: 'Lc score 0 & 2', 
    3: 'Lc score 3 & 4', 
    4: 'Lc score 3 & 4',
    5: 'Lc score 5 & 6',
    6: 'Lc score 5 & 6', 
    '-': np.nan
}

# %%
SKCM_info['Lc_score'] = SKCM_info['LYMPHOCYTE.SCORE'].map(lymphocyte_score_map)

# %%
cancer = 'SKCM'
os.mkdir('./outputs/survival/' + cancer + '/lc_score_boxplot/')
for state in states: 
    print(state)

    score_stage_df = pd.DataFrame(state_scores[cancer][state], columns = [state]).join(SKCM_info['Lc_score']).dropna()

    kruskal = stats.kruskal(score_stage_df[score_stage_df['Lc_score'] == 'Lc score 0 & 2'][state],
                          score_stage_df[score_stage_df['Lc_score'] == 'Lc score 3 & 4'][state],
                          score_stage_df[score_stage_df['Lc_score'] == 'Lc score 5 & 6'][state])
  
        
    if kruskal[1] < 0.05: 
        print('significant!')
        
    order = ['Lc score 0 & 2', 'Lc score 3 & 4', 'Lc score 5 & 6']
    ax = sns.swarmplot(x = 'Lc_score', y = state, data = score_stage_df, color = 'black', zorder = 0, s = 6, order = order)
    ax = sns.boxplot(x = 'Lc_score', y = state, data = score_stage_df, color = 'white', zorder = 4, order = order)
    
    ax.set_xticklabels(['Lc score 0 & 2 (n=' + str(len(score_stage_df[score_stage_df['Lc_score'] == 'Lc score 0 & 2'])) + ')',
                        'Lc score 3 & 4 (n=' + str(len(score_stage_df[score_stage_df['Lc_score'] == 'Lc score 3 & 4'])) + ')',
                        'Lc score 5 & 6 (n=' + str(len(score_stage_df[score_stage_df['Lc_score'] == 'Lc score 5 & 6'])) + ')'])
    plt.xlabel('')
               
    if kruskal[1] < 0.001:
        ax.set_title(cancer + ' H=' + str(round(kruskal[0], 2)) + ' p < 0.001')
    else: 
        ax.set_title(cancer + ' H=' + str(round(kruskal[0], 2)) + ' p=' + str(round(kruskal[1], 3)))
            
    for patch in ax.artists:
        r, g, b, a = patch.get_facecolor()
        patch.set_facecolor((r, g, b, 0))
        
    plt.ylabel(state + ' score')
    plt.tight_layout()
    plt.savefig('./outputs/survival/' + cancer + '/' + 'lc_score_boxplot/' + state + '.pdf')
    plt.close()
# Out:
# CD8B
# significant!
# CXCL16
# significant!
# CXCR6
# significant!
# CXCR3
# significant!
# CXCR2
# significant!
# CCR5
# significant!
# CCR10
# CD4
# significant!
# NK cells
# significant!
# IL12B
# significant!
# /Users/mariusmessemaker/miniconda3/envs/py36-sc/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Univariate CPH

# %%
states = ['CCR1', 'CCR10', 'CCR2', 'CCR3', 'CCR4', 'CCR5', 'CCR6','CCR7', 'CCR8', 
          'CCR9', 'CX3CR1', 'CXCR1', 'CXCR2', 'CXCR3', 'CXCR4', 'CXCR5', 'CXCR6', 'CXCR7', 'XCR1']

# %%
for cancer in cancers:
    print(cancer)
    os.mkdir('./outputs/survival/' + cancer + '/cph/')
    
    cph_concat = {}
    cph_concat['OS'] = pd.DataFrame()
    cph_concat['PFS'] = pd.DataFrame()
    
    for state in states: 
        print(state)
        ix = state_scores[cancer][state].index.values
        
        cph_dict = fit_cph(end1_name = 'OS', end1_time = TCGA_sample_info[TCGA_sample_info['type']==cancer].loc[ix,'OS.time'], end1_event = TCGA_sample_info[TCGA_sample_info['type']==cancer].loc[ix, 'OS'], 
                           end2_name = 'PFS', end2_time = TCGA_survival[TCGA_survival['type']==cancer].loc[ix, 'PFS.time'], end2_event = TCGA_survival[TCGA_survival['type']==cancer].loc[ix, 'PFS'], 
                           var1 = state_scores[cancer][state], var1_name = state)
        
        for end in cph_dict.keys(): 
            
            cph_concat[end] = pd.concat([cph_concat[end], cph_dict[end]['cph']])
            
    
    for end in cph_concat.keys():
        print(end)
        
        
        plot_forest_cph(cph_concat[end], title = cancer + ' ' + end, xlabel = 'log10(HR) (95% CI) (n=' + str(cph_dict[end]['n']) + ')', sort_on_pvalues = True, nan_str = False,   
                        fig_adjust = (5, 1), save = './outputs/survival/' + cancer + '/cph/' + end +'_chemokine_receptors.pdf')
    
        print(cph_dict[end]['na'])
    print('\n')
    print('\n')
# Out:
# BRCA
# CCR1
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.492
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.495
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.5
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.518
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.559
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.559
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 151.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 1094 total observations, 943 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic    p  -log2(p)
# CCR6 km              6.62 0.01      6.63
#      rank            4.92 0.03      5.23
# 1. Variable 'CCR6' failed the non-proportional test: p-value is 0.0101.
#
# Concordance index: 0.56
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 1094 total observations, 890 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic      p  -log2(p)
# CCR6 km              9.93 <0.005      9.27
#      rank            6.90   0.01      6.86
# 1. Variable 'CCR6' failed the non-proportional test: p-value is 0.0016.
#
# Concordance index: 0.578
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.562
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.501
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.562
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.51
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.519
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.518
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.51
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.546
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.572
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.492
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.49
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.564
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.501
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 151.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.583
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 204.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.565
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 1, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 1, 'event': 0}
#
#
#
#
# HNSC
# CCR1
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.521
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.552
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.548
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.561
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.534
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.587
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.585
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.559
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.591
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.58
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.606
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.588
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.518
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.509
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 220.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 519 total observations, 299 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic      p  -log2(p)
# CXCR1 km              8.37 <0.005      8.03
#       rank            8.24 <0.005      7.93
# 1. Variable 'CXCR1' failed the non-proportional test: p-value is 0.0038.
#
# Concordance index: 0.538
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 519 total observations, 248 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic      p  -log2(p)
# CXCR1 km             13.58 <0.005     12.09
#       rank           14.64 <0.005     12.91
# 1. Variable 'CXCR1' failed the non-proportional test: p-value is 0.0001.
#
# Concordance index: 0.531
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.505
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.5
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.568
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.567
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.548
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.546
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.6
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.584
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.568
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.501
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.519
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 220.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.572
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 271.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 1, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 1, 'event': 0}
#
#
#
#
# LUAD
# CCR1
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.614
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 247 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic    p  -log2(p)
# CCR2 km              7.47 0.01      7.32
#      rank            7.34 0.01      7.21
# 1. Variable 'CCR2' failed the non-proportional test: p-value is 0.0063.
#
# Concordance index: 0.584
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.529
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.586
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.567
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.568
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.552
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.608
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 247 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic      p  -log2(p)
# CCR6 km             13.06 <0.005     11.70
#      rank           14.28 <0.005     12.63
# 1. Variable 'CCR6' failed the non-proportional test: p-value is 0.0002.
#
# Concordance index: 0.583
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.585
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 247 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic      p  -log2(p)
# CCR7 km              9.22 <0.005      8.71
#      rank           10.37 <0.005      9.61
# 1. Variable 'CCR7' failed the non-proportional test: p-value is 0.0013.
#
# Concordance index: 0.563
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.533
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.561
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 247 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic    p  -log2(p)
# CCR9 km              6.89 0.01      6.85
#      rank            7.22 0.01      7.11
# 1. Variable 'CCR9' failed the non-proportional test: p-value is 0.0072.
#
# Concordance index: 0.541
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 183.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 323 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#              test_statistic      p  -log2(p)
# CX3CR1 km              9.41 <0.005      8.85
#        rank           10.02 <0.005      9.33
# 1. Variable 'CX3CR1' failed the non-proportional test: p-value is 0.0015.
#
# Concordance index: 0.605
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 247 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#              test_statistic      p  -log2(p)
# CX3CR1 km             12.56 <0.005     11.31
#        rank           12.84 <0.005     11.53
# 1. Variable 'CX3CR1' failed the non-proportional test: p-value is 0.0003.
#
# Concordance index: 0.584
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.496
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.491
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.546
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.567
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.539
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.584
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 506 total observations, 247 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic      p  -log2(p)
# CXCR5 km              8.94 <0.005      8.48
#       rank            8.65 <0.005      8.26
# 1. Variable 'CXCR5' failed the non-proportional test: p-value is 0.0028.
#
# Concordance index: 0.568
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.565
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.52
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 183.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.595
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 259.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.571
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 9, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 9, 'event': 0}
#
#
#
#
# LUSC
# CCR1
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.52
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.532
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.52
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.51
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.531
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.511
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.502
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.517
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.506
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.506
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.498
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.487
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.512
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.499
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 496 total observations, 244 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#              test_statistic    p  -log2(p)
# CX3CR1 km              6.46 0.01      6.50
#        rank            6.32 0.01      6.39
# 1. Variable 'CX3CR1' failed the non-proportional test: p-value is 0.0110.
#
# Concordance index: 0.493
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.513
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.496
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.511
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.522
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.509
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.496
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.505
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.517
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.511
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.497
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 212.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 252.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 6, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 5, 'event': 0}
#
#
#
#
# STAD
# CCR1
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.563
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.561
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.543
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.567
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.544
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.512
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.484
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.51
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.539
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.506
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.544
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.531
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.531
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.509
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.503
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.587
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.569
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.519
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.589
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 157.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 196.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.532
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 6, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 4, 'event': 0}
#
#
#
#
# KIRC
# CCR1
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.543
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.537
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.582
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.563
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.509
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.565
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.507
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.517
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.563
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.566
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.543
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.544
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.534
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.555
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.571
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.595
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.588
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.544
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.555
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.54
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 175.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.6
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 222.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.577
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 0, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 2, 'event': 0}
#
#
#
#
# BLCA
# CCR1
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.517
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.53
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.519
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.515
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.518
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.548
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.544
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.523
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.536
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.518
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.537
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.503
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.521
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.515
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.497
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.537
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 408 total observations, 179 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic    p  -log2(p)
# CXCR2 km              6.64 0.01      6.65
#       rank            7.16 0.01      7.07
# 1. Variable 'CXCR2' failed the non-proportional test: p-value is 0.0075.
#
# Concordance index: 0.532
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.533
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.494
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.501
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.52
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.522
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.552
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.536
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.562
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.534
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 178.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.496
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 229.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.504
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 1, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 0, 'event': 0}
#
#
#
#
# LIHC
# CCR1
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.496
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.538
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.571
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.591
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.562
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.573
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.602
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.583
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.529
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.497
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.536
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.498
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.574
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.499
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.511
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.575
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.569
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.583
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.586
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.536
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.515
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 130.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.568
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 225.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.581
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 1, 'event': 0}
# PFS
# {'XCR1': 0, 'time': 1, 'event': 0}
#
#
#
#
# SKCM
# CCR1
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.61
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: PFS!
#
# CCR10
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.515
# Finished fitting: PFS!
#
# CCR2
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.62
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: PFS!
#
# CCR3
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.593
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.539
# Finished fitting: PFS!
#
# CCR4
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.577
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.521
# Finished fitting: PFS!
#
# CCR5
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.623
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: PFS!
#
# CCR6
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.539
# Finished fitting: PFS!
#
# CCR7
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.583
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: PFS!
#
# CCR8
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.612
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.543
# Finished fitting: PFS!
#
# CCR9
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.576
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: PFS!
#
# CX3CR1
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: PFS!
#
# CXCR1
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# CXCR2
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# CXCR3
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.619
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.557
# Finished fitting: PFS!
#
# CXCR4
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.569
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.521
# Finished fitting: PFS!
#
# CXCR5
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.544
# Finished fitting: PFS!
#
# CXCR6
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.624
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# CXCR7
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.517
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: PFS!
#
# XCR1
# Fitting: OS ...
# Number of events: 213.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.576
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 322.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: PFS!
#
# OS
# {'XCR1': 0, 'time': 15, 'event': 7}
# PFS
# {'XCR1': 0, 'time': 14, 'event': 7}

# %% [markdown]
# ## All cancers multivariate CPH strafified by age and covariate = sex

# %%
states = ['CD8B', 'CXCR6', 'CXCR3', 'CXCR2', 'CCR5', 'CCR10', 'IL12B', 'CD19', 'NK cells', 'CXCL16']

# %%
os.mkdir('./outputs/survival/multivariate_all_cancers/')
for state in states:
    print(state)
    
    cph_concat = {}
    cph_concat['OS'] = pd.DataFrame()
    cph_concat['PFS'] = pd.DataFrame()
    
    for cancer in cancers:
        print(cancer)
        ix = state_scores[cancer][state].index.values
        
        cph_dict = fit_cph(end1_name = 'OS', end1_time = TCGA_sample_info.loc[ix,'OS.time'], end1_event = TCGA_sample_info.loc[ix, 'OS'], 
                           end2_name = 'PFS', end2_time = TCGA_survival.loc[ix, 'PFS.time'], end2_event = TCGA_survival.loc[ix, 'PFS'], 
                           var1 = state_scores[cancer][state], var1_name = state, 
                           var2 = TCGA_sample_info.loc[ix, 'sex'], var2_name = 'Sex', 
                           #var3 =  TCGA_sample_info.loc[ix, 'age_at_initial_pathologic_diagnosis'], var3_name = 'Age', 
                           dummy_var1 = TCGA_sample_info.loc[ix,'tumor_stage'], dummy_var1_name = ('Stage (versus 0 & I)', 'Stage 0 & I'), 
                           advice = False, strata = ['Stage (versus 0 & I)'], drop = ['Sex'])
        
        for end in cph_dict.keys():
            print(end)
            print(cph_dict[end]['n'])
            print(cph_dict[end]['na'])
            
            cph_dict[end]['cph'].index = cancer + ' ' + cph_dict[end]['cph'].index 
            cph_concat[end] = pd.concat([cph_concat[end], cph_dict[end]['cph']])
        
    for end in cph_concat.keys():

        plot_forest_cph(cph_concat[end], title = end, xlabel = 'log10(HR) (95% CI)', sort_on_pvalues = True, nan_str = False, 
                        fig_adjust = (5, 1.25), save = './outputs/survival/multivariate_all_cancers/' + end + '_' + state +'.pdf')
    
    print('\n')
    print('\n')
# Out:
# CD8B
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.579
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.568
# Finished fitting: PFS!
#
# OS
# 1070
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.555
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: PFS!
#
# OS
# 444
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.543
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: PFS!
#
# OS
# 498
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: PFS!
#
# OS
# 491
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 384 total observations, 237 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#            test_statistic    p  -log2(p)
# CD8B km              0.51 0.48      1.07
#      rank            6.04 0.01      6.16
# Sex  km              0.00 0.97      0.04
#      rank            1.13 0.29      1.80
# 1. Variable 'CD8B' failed the non-proportional test: p-value is 0.0140.
#
# Concordance index: 0.537
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: PFS!
#
# OS
# 384
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.524
# Finished fitting: PFS!
#
# OS
# 530
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.53
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.523
# Finished fitting: PFS!
#
# OS
# 405
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.561
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.563
# Finished fitting: PFS!
#
# OS
# 346
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.628
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# OS
# 408
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CD8B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CXCR6
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.572
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.566
# Finished fitting: PFS!
#
# OS
# 1070
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.574
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.573
# Finished fitting: PFS!
#
# OS
# 444
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: PFS!
#
# OS
# 498
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.512
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.51
# Finished fitting: PFS!
#
# OS
# 491
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.536
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: PFS!
#
# OS
# 384
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.499
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.513
# Finished fitting: PFS!
#
# OS
# 530
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.537
# Finished fitting: PFS!
#
# OS
# 405
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.574
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.565
# Finished fitting: PFS!
#
# OS
# 346
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.628
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: PFS!
#
# OS
# 408
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CXCR6': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CXCR3
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.566
# Finished fitting: PFS!
#
# OS
# 1070
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.584
# Finished fitting: PFS!
#
# OS
# 444
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.552
# Finished fitting: PFS!
#
# OS
# 498
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.5
# Finished fitting: PFS!
#
# OS
# 491
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.519
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.531
# Finished fitting: PFS!
#
# OS
# 384
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.511
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.53
# Finished fitting: PFS!
#
# OS
# 530
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.538
# Finished fitting: PFS!
#
# OS
# 405
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.569
# Finished fitting: PFS!
#
# OS
# 346
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.624
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.568
# Finished fitting: PFS!
#
# OS
# 408
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CXCR3': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CXCR2
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: PFS!
#
# OS
# 1070
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.546
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.54
# Finished fitting: PFS!
#
# OS
# 444
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# OS
# 498
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.521
# Finished fitting: PFS!
#
# OS
# 491
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.517
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.54
# Finished fitting: PFS!
#
# OS
# 384
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.521
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.539
# Finished fitting: PFS!
#
# OS
# 530
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.547
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.541
# Finished fitting: PFS!
#
# OS
# 405
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.532
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: PFS!
#
# OS
# 346
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.552
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.522
# Finished fitting: PFS!
#
# OS
# 408
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CXCR2': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CCR5
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.57
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.562
# Finished fitting: PFS!
#
# OS
# 1070
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.57
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.572
# Finished fitting: PFS!
#
# OS
# 444
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.546
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.53
# Finished fitting: PFS!
#
# OS
# 498
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.519
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.506
# Finished fitting: PFS!
#
# OS
# 491
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.52
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.532
# Finished fitting: PFS!
#
# OS
# 384
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.506
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: PFS!
#
# OS
# 530
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: PFS!
#
# OS
# 405
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.554
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.564
# Finished fitting: PFS!
#
# OS
# 346
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.627
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: PFS!
#
# OS
# 408
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CCR5': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CCR10
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.577
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.533
# Finished fitting: PFS!
#
# OS
# 1070
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.581
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.574
# Finished fitting: PFS!
#
# OS
# 444
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.505
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# OS
# 498
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: PFS!
#
# OS
# 491
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.559
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 386 total observations, 202 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic    p  -log2(p)
# CCR10 km              1.09 0.30      1.75
#       rank            7.72 0.01      7.51
# Sex   km              0.00 0.97      0.05
#       rank            2.66 0.10      3.28
# 1. Variable 'CCR10' failed the non-proportional test: p-value is 0.0055.
#
# Concordance index: 0.58
# Finished fitting: PFS!
#
# OS
# 384
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: PFS!
#
# OS
# 530
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 405 total observations, 228 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic      p  -log2(p)
# CCR10 km              3.67   0.06      4.18
#       rank            9.56 <0.005      8.97
# Sex   km              0.05   0.82      0.28
#       rank            0.56   0.46      1.13
# 1. Variable 'CCR10' failed the non-proportional test: p-value is 0.0020.
#
# Concordance index: 0.541
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 406 total observations, 178 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#             test_statistic      p  -log2(p)
# CCR10 km              1.59   0.21      2.27
#       rank           13.58 <0.005     12.10
# Sex   km              0.49   0.48      1.05
#       rank            2.77   0.10      3.38
# 1. Variable 'CCR10' failed the non-proportional test: p-value is 0.0002.
#
# Concordance index: 0.539
# Finished fitting: PFS!
#
# OS
# 405
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# OS
# 346
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: PFS!
#
# OS
# 408
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CCR10': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# IL12B
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.587
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.601
# Finished fitting: PFS!
#
# OS
# 1070
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.556
# Finished fitting: PFS!
#
# OS
# 444
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.575
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.55
# Finished fitting: PFS!
#
# OS
# 498
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.512
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.503
# Finished fitting: PFS!
#
# OS
# 491
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.534
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.56
# Finished fitting: PFS!
#
# OS
# 384
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.537
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: PFS!
#
# OS
# 530
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.553
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: PFS!
#
# OS
# 405
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.537
# Finished fitting: PFS!
#
# OS
# 346
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.591
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.539
# Finished fitting: PFS!
#
# OS
# 408
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'IL12B': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CD19
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.575
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.581
# Finished fitting: PFS!
#
# OS
# 1070
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.622
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.613
# Finished fitting: PFS!
#
# OS
# 444
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.558
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.538
# Finished fitting: PFS!
#
# OS
# 498
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.532
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.51
# Finished fitting: PFS!
#
# OS
# 491
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.567
# Finished fitting: PFS!
#
# OS
# 384
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.532
# Finished fitting: PFS!
#
# OS
# 530
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.525
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.53
# Finished fitting: PFS!
#
# OS
# 405
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.529
# Finished fitting: PFS!
#
# OS
# 346
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.586
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.549
# Finished fitting: PFS!
#
# OS
# 408
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CD19': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# NK cells
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.57
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.552
# Finished fitting: PFS!
#
# OS
# 1070
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.566
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.551
# Finished fitting: PFS!
#
# OS
# 444
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.484
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.503
# Finished fitting: PFS!
#
# OS
# 498
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.523
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.503
# Finished fitting: PFS!
#
# OS
# 491
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.522
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.535
# Finished fitting: PFS!
#
# OS
# 384
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: PFS!
#
# OS
# 530
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.545
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.533
# Finished fitting: PFS!
#
# OS
# 405
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.571
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.578
# Finished fitting: PFS!
#
# OS
# 346
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.587
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.542
# Finished fitting: PFS!
#
# OS
# 408
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'NK cells': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}
#
#
#
#
# CXCL16
# BRCA
# Fitting: OS ...
# Number of events: 140.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.54
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 191.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 1070 total observations, 879 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#              test_statistic    p  -log2(p)
# CXCL16 km              7.03 0.01      6.96
#        rank            0.12 0.73      0.46
# Sex    km              0.38 0.54      0.90
#        rank            1.59 0.21      2.27
# 1. Variable 'CXCL16' failed the non-proportional test: p-value is 0.0080.
#
# Concordance index: 0.518
# Finished fitting: PFS!
#
# OS
# 1070
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 1070
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# HNSC
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.526
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 234.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.54
# Finished fitting: PFS!
#
# OS
# 444
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# PFS
# 444
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 75, 'time': 1, 'event': 0}
# LUAD
# Fitting: OS ...
# Number of events: 181.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.562
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 256.0
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 498 total observations, 242 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#              test_statistic    p  -log2(p)
# CXCL16 km              6.73 0.01      6.72
#        rank            3.07 0.08      3.65
# Sex    km              3.01 0.08      3.60
#        rank            0.08 0.78      0.36
# 1. Variable 'CXCL16' failed the non-proportional test: p-value is 0.0095.
#
# Concordance index: 0.559
# Finished fitting: PFS!
#
# OS
# 498
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# PFS
# 498
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 8, 'time': 9, 'event': 0}
# LUSC
# Fitting: OS ...
# Number of events: 210.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.548
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 250.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.527
# Finished fitting: PFS!
#
# OS
# 491
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 6, 'event': 0}
# PFS
# 492
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 4, 'time': 5, 'event': 0}
# STAD
# Fitting: OS ...
# Number of events: 147.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.514
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 184.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.536
# Finished fitting: PFS!
#
# OS
# 384
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 6, 'event': 0}
# PFS
# 386
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 25, 'time': 4, 'event': 0}
# KIRC
# Fitting: OS ...
# Number of events: 174.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.508
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 221.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: PFS!
#
# OS
# 530
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 0, 'event': 0}
# PFS
# 528
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 3, 'time': 2, 'event': 0}
# BLCA
# Fitting: OS ...
# Number of events: 177.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.53
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 228.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.528
# Finished fitting: PFS!
#
# OS
# 405
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 1, 'event': 0}
# PFS
# 406
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 2, 'time': 0, 'event': 0}
# LIHC
# Fitting: OS ...
# Number of events: 116.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.52
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 208.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.516
# Finished fitting: PFS!
#
# OS
# 346
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# PFS
# 346
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 24, 'time': 1, 'event': 0}
# SKCM
# Fitting: OS ...
# Number of events: 189.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.573
# Finished fitting: OS!
#
# Fitting: PFS ...
# Number of events: 287.0
# Proportional hazard assumption looks okay.
# Concordance index: 0.54
# Finished fitting: PFS!
#
# OS
# 408
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 9, 'event': 7}
# PFS
# 409
# {'CXCL16': 0, 'Sex': 0, 'Stage (versus 0 & I)': 52, 'time': 8, 'event': 7}

# %% [markdown]
# ## Kaplan Meiers

# %%
states = ['CD8B', 'CXCR6', 'CXCR3', 'CXCR2', 'CCR5', 'CCR10', 'IL12B', 'CXCL16', 'NK cells', 'CD19']

# %%
quantile = 1/3
for cancer in cancers:
    print(cancer)
    os.mkdir('./outputs/survival/' + cancer + '/kaplan_meier/')
    # dichotomize patients into botom 1/3 and top 1/3 groups using the state signature scores: 
    state_scores_0 = {}
    state_scores_66 = {}

    for state in states: 
        cmask = (state_scores[cancer][state] <= state_scores[cancer][state].quantile(q = quantile))
        state_scores_0[state] = state_scores[cancer][state][cmask]
        print('Number of patients in 0_33 group '+ state + ':', len(state_scores_0[state]))
        print(state_scores_0[state].min(), state_scores_0[state].max(), '\n')
    
        cmask = (state_scores[cancer][state] >= state_scores[cancer][state].quantile(q = 2*quantile))
        state_scores_66[state] = state_scores[cancer][state][cmask]
        print('Number of patients in 67-100 group '+ state + ':', len(state_scores_66[state]))
        print(state_scores_66[state].min(), state_scores_66[state].max(), '\n')
    
    # Extract OS_time/event and PFS_time/event: 

    OS_time = TCGA_sample_info[TCGA_sample_info['type']==cancer]['OS.time']
    OS_status = TCGA_sample_info[TCGA_sample_info['type']==cancer]['OS']
    PFS_time =TCGA_survival[TCGA_survival['type']==cancer]['PFS.time']
    PFS_status = TCGA_survival[TCGA_survival['type']==cancer]['PFS']

    # Fit KaplanMeier PFS and plot:  
    for state in states:
        print('PFS: ', state)
        ix0 = state_scores_0[state].index.values 
        ix67 = state_scores_66[state].index.values 
        
        cph_test_0 = pd.DataFrame({'PFS_time': PFS_time[ix0].dropna()/365, 
                                   'ix': 0, 
                                   'PFS_event': PFS_status[PFS_time[ix0].dropna().index.values].dropna()}) # here you can do the last .dropna() because you fill ix with dummy 0 
        
        cph_test_67 = pd.DataFrame({'PFS_time': PFS_time[ix67].dropna()/365, 
                                    'ix': 1, 
                                    'PFS_event': PFS_status[PFS_time[ix67].dropna().index.values].dropna()}) # here you can do the last.dropna() because you fill ix with dummy 1
        
        print('Number of events ix0:', PFS_status[PFS_time[ix0].dropna().index.values].dropna().sum(), 'Number of missing values ix0:', PFS_status[PFS_time[ix0].dropna().index.values].isna().sum())
        print('Number of events ix67:', PFS_status[PFS_time[ix67].dropna().index.values].dropna().sum(), 'Number of missing values ix67:', PFS_status[PFS_time[ix67].dropna().index.values].isna().sum())
        
        cph_test = pd.concat([cph_test_0, cph_test_67]) 
        
        cph = CoxPHFitter()
        cph.fit(cph_test, duration_col='PFS_time', event_col='PFS_event')
        cph.check_assumptions(cph_test)
        
        kmf_0 = KaplanMeierFitter() 
        kmf_67 = KaplanMeierFitter()

        kmf_0.fit(PFS_time[ix0].dropna()/365, 
                  PFS_status[PFS_time[ix0].dropna().index.values].dropna(), 
                  timeline = np.arange(0, 10, 0.005),
                  label = 'Low (n=' + str(len(PFS_time[ix0].dropna())) + ')')
        ax = kmf_0.plot(ci_show = False, color = 'black', show_censors = True, censor_styles={'marker': 2, 'ms':5, 'lw':0.5})

        
        kmf_67.fit(PFS_time[ix67].dropna()/365, 
                   PFS_status[PFS_time[ix67].dropna().index.values].dropna(),
                   timeline = np.arange(0, 10, 0.005),
                   label = 'High (n=' + str(len(PFS_time[ix67].dropna())) + ')')
        ax = kmf_67.plot(ci_show = False, color = 'red', show_censors = True, censor_styles={'marker': 2, 'ms':5, 'lw':0.5})
        
        ax.text(0.01, 0.01, 'HR '+str(round(cph.summary.loc['ix', 'exp(coef)'], 2))+' ('+str(round(cph.summary.loc['ix', 'exp(coef) lower 95%'],2))+'-'+str(round(cph.summary.loc['ix', 'exp(coef) upper 95%'],2))+')'+'\n'+'p='+str(round(cph.summary.loc['ix', 'p'], 10)),
                ha='left', va='bottom', transform=ax.transAxes)
            
        #add_at_risk_counts(kmf_0, kmf_67, ax=ax)
        plt.title(cancer + ' PFS ' + state)
        plt.tight_layout()
        plt.savefig('./outputs/survival/' + cancer + '/kaplan_meier/PFS_km_33_' + state + '.pdf', dpi = 400)
        plt.close()
    
    # to make OS and PFS completely separate initialize a new for loop: 
    for state in states:
        print('OS: ', state)
        ix0 = state_scores_0[state].index.values 
        ix67 = state_scores_66[state].index.values 
        
        cph_test_0 = pd.DataFrame({'OS_time': OS_time[ix0].dropna()/365, 
                                    'ix': 0, 
                                    'OS_event': OS_status[OS_time[ix0].dropna().index.values].dropna()}) # here you can do the last .dropna() because you fill ix with dummy 0 
        
        cph_test_67 = pd.DataFrame({'OS_time': OS_time[ix67].dropna()/365, 
                                    'ix': 1, 
                                    'OS_event': OS_status[OS_time[ix67].dropna().index.values].dropna()}) # here you can do the last .dropna() because you fill ix with dummy 1 
        
        print('Number of events ix0:', OS_status[OS_time[ix0].dropna().index.values].dropna().sum(), 'Number of missing values ix0:', OS_status[OS_time[ix0].dropna().index.values].isna().sum())
        print('Number of events ix67:', OS_status[OS_time[ix67].dropna().index.values].dropna().sum(), 'Number of missing values ix67:', OS_status[OS_time[ix67].dropna().index.values].isna().sum())
        
        cph_test = pd.concat([cph_test_0, cph_test_67]) 
        
        cph = CoxPHFitter()
        cph.fit(cph_test, duration_col='OS_time', event_col='OS_event')
        cph.check_assumptions(cph_test)
        
        kmf_0 = KaplanMeierFitter() 
        kmf_67 = KaplanMeierFitter()

        kmf_0.fit(OS_time[ix0].dropna()/365, 
                  OS_status[OS_time[ix0].dropna().index.values].dropna(),
                  timeline = np.arange(0, 10, 0.005),
                  label = 'Low (n=' + str(len(OS_time[ix0].dropna())) + ')')
        ax = kmf_0.plot(ci_show = False, color = 'black', show_censors = True, censor_styles={'marker': 2, 'ms':5, 'lw':0.5})
        
        kmf_67.fit(OS_time[ix67].dropna()/365, 
                   OS_status[OS_time[ix67].dropna().index.values].dropna(),
                   timeline = np.arange(0, 10, 0.005),
                   label = 'High (n=' + str(len(OS_time[ix67].dropna())) + ')')
        ax = kmf_67.plot(ci_show = False, color = 'red', show_censors = True, censor_styles={'marker': 2, 'ms':5, 'lw':0.5})
        
        ax.text(0.01, 0.01, 'HR '+str(round(cph.summary.loc['ix', 'exp(coef)'], 2))+' ('+str(round(cph.summary.loc['ix', 'exp(coef) lower 95%'],2))+'-'+str(round(cph.summary.loc['ix', 'exp(coef) upper 95%'],2))+')'+'\n'+'p='+str(round(cph.summary.loc['ix', 'p'], 10)),
                ha='left', va='bottom', transform=ax.transAxes)
        
        #add_at_risk_counts(kmf_0, kmf_67, ax=ax)
        plt.title(cancer + ' OS ' + state)
        plt.tight_layout()
        plt.savefig('./outputs/survival/' + cancer + '/kaplan_meier/OS_km_33_' + state + '.pdf', dpi = 400)
        plt.close()
        
    print('\n')
    print('\n')
# Out:
# BRCA
# Number of patients in 0_33 group CD8B: 365
# -3.36906952828317 -0.3797748698479904
#
# Number of patients in 67-100 group CD8B: 365
# 0.46397804076015414 2.925674533481078
#
# Number of patients in 0_33 group CXCR6: 365
# -3.315627990370191 -0.4318423731465461
#
# Number of patients in 67-100 group CXCR6: 365
# 0.4596873084543077 2.7074374084166895
#
# Number of patients in 0_33 group CXCR3: 365
# -3.5641891989573553 -0.38450408689199633
#
# Number of patients in 67-100 group CXCR3: 365
# 0.4068573531684912 2.510956860210585
#
# Number of patients in 0_33 group CXCR2: 365
# -3.1549186452901568 -0.3048504812409999
#
# Number of patients in 67-100 group CXCR2: 365
# 0.42487742543984863 5.069117017843321
#
# Number of patients in 0_33 group CCR5: 365
# -4.024744375427019 -0.4232818580538839
#
# Number of patients in 67-100 group CCR5: 365
# 0.46663258730890633 2.8339548726892962
#
# Number of patients in 0_33 group CCR10: 365
# -3.235943817821323 -0.4568297614025395
#
# Number of patients in 67-100 group CCR10: 365
# 0.39816132184032244 3.835429571433662
#
# Number of patients in 0_33 group IL12B: 365
# -1.6520812867299093 -0.5097525289525385
#
# Number of patients in 67-100 group IL12B: 365
# 0.49030754924879655 2.6753645338757712
#
# Number of patients in 0_33 group CXCL16: 365
# -3.7626070419920037 -0.39305688762880464
#
# Number of patients in 67-100 group CXCL16: 365
# 0.3663419642323125 3.6772958962333044
#
# Number of patients in 0_33 group NK cells: 365
# -1.8017219674591667 -0.48697892554052935
#
# Number of patients in 67-100 group NK cells: 365
# 0.22621096278501895 3.816747305816859
#
# Number of patients in 0_33 group CD19: 365
# -1.456117833580244 -0.600547950455865
#
# Number of patients in 67-100 group CD19: 365
# 0.39260293679607083 3.2396608959394246
#
# PFS:  CD8B
# Number of events ix0: 76.0 Number of missing values ix0: 0
# Number of events ix67: 62.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 83.0 Number of missing values ix0: 0
# Number of events ix67: 55.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 84.0 Number of missing values ix0: 0
# Number of events ix67: 55.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 83.0 Number of missing values ix0: 0
# Number of events ix67: 61.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 89.0 Number of missing values ix0: 0
# Number of events ix67: 55.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 78.0 Number of missing values ix0: 0
# Number of events ix67: 61.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 86.0 Number of missing values ix0: 0
# Number of events ix67: 50.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 79.0 Number of missing values ix0: 0
# Number of events ix67: 58.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 82.0 Number of missing values ix0: 0
# Number of events ix67: 50.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 90.0 Number of missing values ix0: 0
# Number of events ix67: 54.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 56.0 Number of missing values ix0: 0
# Number of events ix67: 45.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 61.0 Number of missing values ix0: 0
# Number of events ix67: 39.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 61.0 Number of missing values ix0: 0
# Number of events ix67: 40.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 61.0 Number of missing values ix0: 0
# Number of events ix67: 46.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 64.0 Number of missing values ix0: 0
# Number of events ix67: 39.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 63.0 Number of missing values ix0: 0
# Number of events ix67: 42.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 64.0 Number of missing values ix0: 0
# Number of events ix67: 42.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 62.0 Number of missing values ix0: 0
# Number of events ix67: 43.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 65.0 Number of missing values ix0: 0
# Number of events ix67: 37.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 67.0 Number of missing values ix0: 0
# Number of events ix67: 42.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# HNSC
# Number of patients in 0_33 group CD8B: 173
# -2.97037139116653 -0.38265455530857445
#
# Number of patients in 67-100 group CD8B: 174
# 0.46140930059853563 2.2542303236346446
#
# Number of patients in 0_33 group CXCR6: 173
# -3.024227093232007 -0.3746583033923622
#
# Number of patients in 67-100 group CXCR6: 174
# 0.46280862482798923 2.2616497022107174
#
# Number of patients in 0_33 group CXCR3: 173
# -3.3440505729129173 -0.4056215473672137
#
# Number of patients in 67-100 group CXCR3: 174
# 0.4387877366814668 2.450275306729162
#
# Number of patients in 0_33 group CXCR2: 174
# -3.2793275181086043 -0.4564430526835954
#
# Number of patients in 67-100 group CXCR2: 174
# 0.46308627143145115 2.869290973064007
#
# Number of patients in 0_33 group CCR5: 173
# -3.0010101986355964 -0.4189344835838807
#
# Number of patients in 67-100 group CCR5: 174
# 0.5034338532093859 2.2445278750539877
#
# Number of patients in 0_33 group CCR10: 173
# -2.651476137580114 -0.4477864155055813
#
# Number of patients in 67-100 group CCR10: 174
# 0.2659839843411157 3.3332363836024967
#
# Number of patients in 0_33 group IL12B: 174
# -1.764885922843542 -0.5118094307381548
#
# Number of patients in 67-100 group IL12B: 174
# 0.39319361170304507 2.77687413776051
#
# Number of patients in 0_33 group CXCL16: 173
# -3.3576478394249474 -0.3781102828539479
#
# Number of patients in 67-100 group CXCL16: 174
# 0.41311324651789244 2.614518097965012
#
# Number of patients in 0_33 group NK cells: 173
# -1.7922846548772293 -0.49565008116537973
#
# Number of patients in 67-100 group NK cells: 174
# 0.32227239506347605 3.378376620337728
#
# Number of patients in 0_33 group CD19: 174
# -1.8527027843067194 -0.5044304111940099
#
# Number of patients in 67-100 group CD19: 174
# 0.32601879724151794 3.594959470862091
#
# PFS:  CD8B
# Number of events ix0: 102.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 104.0 Number of missing values ix0: 0
# Number of events ix67: 79.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 105.0 Number of missing values ix0: 0
# Number of events ix67: 80.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 94.0 Number of missing values ix0: 0
# Number of events ix67: 94.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 108.0 Number of missing values ix0: 0
# Number of events ix67: 87.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 102.0 Number of missing values ix0: 0
# Number of events ix67: 72.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 95.0 Number of missing values ix0: 0
# Number of events ix67: 81.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 89.0 Number of missing values ix0: 0
# Number of events ix67: 92.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 99.0 Number of missing values ix0: 0
# Number of events ix67: 91.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 114.0 Number of missing values ix0: 0
# Number of events ix67: 69.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 81.0 Number of missing values ix0: 0
# Number of events ix67: 65.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 85.0 Number of missing values ix0: 0
# Number of events ix67: 61.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 84.0 Number of missing values ix0: 0
# Number of events ix67: 62.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 78.0 Number of missing values ix0: 0
# Number of events ix67: 76.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 87.0 Number of missing values ix0: 0
# Number of events ix67: 69.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 81.0 Number of missing values ix0: 0
# Number of events ix67: 57.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 81.0 Number of missing values ix0: 0
# Number of events ix67: 63.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 71.0 Number of missing values ix0: 0
# Number of events ix67: 81.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 73.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 97.0 Number of missing values ix0: 0
# Number of events ix67: 55.0 Number of missing values ix67: 0
# The ``p_value_threshold`` is set at 0.01. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 347 total observations, 195 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#          test_statistic    p  -log2(p)
# ix km              4.75 0.03      5.10
#    rank            6.69 0.01      6.68
# 1. Variable 'ix' failed the non-proportional test: p-value is 0.0097.
#
#    Advice: with so few unique values (only 2), you can include `strata=['ix', ...]` in the call in
# `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
#
#
#
#
# LUAD
# Number of patients in 0_33 group CD8B: 172
# -3.2248854660298383 -0.4277101905591369
#
# Number of patients in 67-100 group CD8B: 172
# 0.4429544259680269 2.6578710336133984
#
# Number of patients in 0_33 group CXCR6: 172
# -4.425468462500174 -0.4722008367657788
#
# Number of patients in 67-100 group CXCR6: 172
# 0.4310071209453733 2.8131519783741443
#
# Number of patients in 0_33 group CXCR3: 172
# -3.6289326876537413 -0.4443338040048026
#
# Number of patients in 67-100 group CXCR3: 172
# 0.45593869946278964 3.2746359598045602
#
# Number of patients in 0_33 group CXCR2: 172
# -3.675206400831169 -0.456667151952768
#
# Number of patients in 67-100 group CXCR2: 172
# 0.4555506391631498 2.795635359204796
#
# Number of patients in 0_33 group CCR5: 172
# -3.128991669965957 -0.4260676442518078
#
# Number of patients in 67-100 group CCR5: 172
# 0.5140528168589494 2.3298730094224602
#
# Number of patients in 0_33 group CCR10: 172
# -3.282857894966253 -0.4755681221196202
#
# Number of patients in 67-100 group CCR10: 172
# 0.25250863012341335 3.5000735272064047
#
# Number of patients in 0_33 group IL12B: 172
# -2.6385309906221255 -0.37664378048143676
#
# Number of patients in 67-100 group IL12B: 172
# 0.48664889687703466 4.171498298955648
#
# Number of patients in 0_33 group CXCL16: 172
# -4.493273536016876 -0.24923206650004756
#
# Number of patients in 67-100 group CXCL16: 172
# 0.47634508992495234 2.7530969310907345
#
# Number of patients in 0_33 group NK cells: 172
# -2.1464129840609254 -0.46515311989092956
#
# Number of patients in 67-100 group NK cells: 172
# 0.3516540702012383 3.3972606626558766
#
# Number of patients in 0_33 group CD19: 172
# -2.8541924807368213 -0.3954694442225791
#
# Number of patients in 67-100 group CD19: 172
# 0.5540466759666486 2.243825968427779
#
# PFS:  CD8B
# Number of events ix0: 95.0 Number of missing values ix0: 0
# Number of events ix67: 87.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 100.0 Number of missing values ix0: 0
# Number of events ix67: 74.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 96.0 Number of missing values ix0: 0
# Number of events ix67: 79.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 92.0 Number of missing values ix0: 0
# Number of events ix67: 77.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 98.0 Number of missing values ix0: 0
# Number of events ix67: 78.0 Number of missing values ix67: 0
# The ``p_value_threshold`` is set at 0.01. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 338 total observations, 162 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#          test_statistic      p  -log2(p)
# ix km              9.86 <0.005      9.21
#    rank            9.26 <0.005      8.74
# 1. Variable 'ix' failed the non-proportional test: p-value is 0.0017.
#
#    Advice: with so few unique values (only 2), you can include `strata=['ix', ...]` in the call in
# `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
# PFS:  CCR10
# Number of events ix0: 85.0 Number of missing values ix0: 0
# Number of events ix67: 83.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 92.0 Number of missing values ix0: 0
# Number of events ix67: 78.0 Number of missing values ix67: 0
# The ``p_value_threshold`` is set at 0.01. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 337 total observations, 167 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#          test_statistic      p  -log2(p)
# ix km             10.23 <0.005      9.50
#    rank            8.86 <0.005      8.42
# 1. Variable 'ix' failed the non-proportional test: p-value is 0.0014.
#
#    Advice: with so few unique values (only 2), you can include `strata=['ix', ...]` in the call in
# `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
# PFS:  CXCL16
# Number of events ix0: 94.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 98.0 Number of missing values ix0: 0
# Number of events ix67: 80.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 99.0 Number of missing values ix0: 0
# Number of events ix67: 78.0 Number of missing values ix67: 0
# The ``p_value_threshold`` is set at 0.01. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 338 total observations, 161 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#          test_statistic      p  -log2(p)
# ix km              8.91 <0.005      8.46
#    rank            9.74 <0.005      9.12
# 1. Variable 'ix' failed the non-proportional test: p-value is 0.0018.
#
#    Advice: with so few unique values (only 2), you can include `strata=['ix', ...]` in the call in
# `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
# OS:  CD8B
# Number of events ix0: 68.0 Number of missing values ix0: 0
# Number of events ix67: 59.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 75.0 Number of missing values ix0: 0
# Number of events ix67: 48.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 72.0 Number of missing values ix0: 0
# Number of events ix67: 55.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 66.0 Number of missing values ix0: 0
# Number of events ix67: 46.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 77.0 Number of missing values ix0: 0
# Number of events ix67: 48.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 59.0 Number of missing values ix0: 0
# Number of events ix67: 59.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 76.0 Number of missing values ix0: 0
# Number of events ix67: 54.0 Number of missing values ix67: 0
# The ``p_value_threshold`` is set at 0.01. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 337 total observations, 207 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#          test_statistic      p  -log2(p)
# ix km              7.92 <0.005      7.68
#    rank            5.44   0.02      5.67
# 1. Variable 'ix' failed the non-proportional test: p-value is 0.0049.
#
#    Advice: with so few unique values (only 2), you can include `strata=['ix', ...]` in the call in
# `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
# OS:  CXCL16
# Number of events ix0: 69.0 Number of missing values ix0: 0
# Number of events ix67: 54.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 67.0 Number of missing values ix0: 0
# Number of events ix67: 57.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 78.0 Number of missing values ix0: 0
# Number of events ix67: 48.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# LUSC
# Number of patients in 0_33 group CD8B: 167
# -3.0781257009309337 -0.3944814966347303
#
# Number of patients in 67-100 group CD8B: 167
# 0.40602096508853586 4.0434061256400335
#
# Number of patients in 0_33 group CXCR6: 167
# -3.861502447603206 -0.40194554578002517
#
# Number of patients in 67-100 group CXCR6: 167
# 0.4955615195910406 2.8807531803833544
#
# Number of patients in 0_33 group CXCR3: 167
# -3.3073866136032524 -0.41410168172087525
#
# Number of patients in 67-100 group CXCR3: 167
# 0.4891271649970565 2.223674994135732
#
# Number of patients in 0_33 group CXCR2: 167
# -2.7818337505987896 -0.49763006418979455
#
# Number of patients in 67-100 group CXCR2: 167
# 0.4109608610977626 3.088772107527189
#
# Number of patients in 0_33 group CCR5: 167
# -3.3426888703080277 -0.39156744599301313
#
# Number of patients in 67-100 group CCR5: 167
# 0.4536803971388816 1.9860520512225226
#
# Number of patients in 0_33 group CCR10: 167
# -3.430342638108323 -0.47398527642252763
#
# Number of patients in 67-100 group CCR10: 167
# 0.36366814979324874 3.893769125719743
#
# Number of patients in 0_33 group IL12B: 167
# -1.9784188012627983 -0.4612512576566223
#
# Number of patients in 67-100 group IL12B: 167
# 0.4721851785461162 3.5164804912958556
#
# Number of patients in 0_33 group CXCL16: 167
# -3.4073364354822955 -0.38241412437259426
#
# Number of patients in 67-100 group CXCL16: 167
# 0.506531467399399 3.423719046149646
#
# Number of patients in 0_33 group NK cells: 167
# -1.9635466032939028 -0.41113243045997766
#
# Number of patients in 67-100 group NK cells: 167
# 0.4025229600324127 3.0639998507324524
#
# Number of patients in 0_33 group CD19: 167
# -2.6309967043203213 -0.40018489222075293
#
# Number of patients in 67-100 group CD19: 167
# 0.5513401918093803 3.412756147083036
#
# PFS:  CD8B
# Number of events ix0: 88.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 81.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 88.0 Number of missing values ix0: 0
# Number of events ix67: 82.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 88.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 84.0 Number of missing values ix0: 0
# Number of events ix67: 90.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 82.0 Number of missing values ix0: 0
# Number of events ix67: 85.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 72.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 79.0 Number of missing values ix0: 0
# Number of events ix67: 83.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 79.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 88.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 71.0 Number of missing values ix0: 0
# Number of events ix67: 74.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 65.0 Number of missing values ix0: 0
# Number of events ix67: 70.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 70.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 75.0 Number of missing values ix0: 0
# Number of events ix67: 71.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 67.0 Number of missing values ix0: 0
# Number of events ix67: 75.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 70.0 Number of missing values ix0: 0
# Number of events ix67: 73.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 63.0 Number of missing values ix0: 0
# Number of events ix67: 69.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 62.0 Number of missing values ix0: 0
# Number of events ix67: 72.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 64.0 Number of missing values ix0: 0
# Number of events ix67: 75.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 70.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# STAD
# Number of patients in 0_33 group CD8B: 138
# -2.7625726423749075 -0.3522977782167662
#
# Number of patients in 67-100 group CD8B: 139
# 0.4734044230673339 3.2096084348929677
#
# Number of patients in 0_33 group CXCR6: 138
# -3.1737549532645764 -0.404103834573455
#
# Number of patients in 67-100 group CXCR6: 139
# 0.545636235484665 2.4162776792004177
#
# Number of patients in 0_33 group CXCR3: 138
# -3.111636049630288 -0.4164287045298943
#
# Number of patients in 67-100 group CXCR3: 139
# 0.4005727648798718 2.6576519826457035
#
# Number of patients in 0_33 group CXCR2: 138
# -2.6605001627511915 -0.5500464084967381
#
# Number of patients in 67-100 group CXCR2: 139
# 0.3514641379483848 3.0520093684388145
#
# Number of patients in 0_33 group CCR5: 138
# -3.558896629093519 -0.3937853171192726
#
# Number of patients in 67-100 group CCR5: 139
# 0.5053232829253496 2.3249045606727514
#
# Number of patients in 0_33 group CCR10: 139
# -4.369793528297351 -0.46512358699338946
#
# Number of patients in 67-100 group CCR10: 139
# 0.37532939267837917 3.193618245775288
#
# Number of patients in 0_33 group IL12B: 138
# -1.8053022194783424 -0.4576973318691126
#
# Number of patients in 67-100 group IL12B: 139
# 0.41683516141385063 3.4582044919028365
#
# Number of patients in 0_33 group CXCL16: 138
# -3.6238811242424944 -0.27704862836002236
#
# Number of patients in 67-100 group CXCL16: 139
# 0.5067811419485425 3.261485267085993
#
# Number of patients in 0_33 group NK cells: 138
# -2.3646012250972954 -0.34059509112909436
#
# Number of patients in 67-100 group NK cells: 139
# 0.38967312621981276 2.668141924276439
#
# Number of patients in 0_33 group CD19: 138
# -2.4719194852541957 -0.43175231887050786
#
# Number of patients in 67-100 group CD19: 139
# 0.4545352965888912 3.0002362338983795
#
# PFS:  CD8B
# Number of events ix0: 58.0 Number of missing values ix0: 0
# Number of events ix67: 70.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 60.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 65.0 Number of missing values ix0: 0
# Number of events ix67: 65.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 67.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 61.0 Number of missing values ix0: 0
# Number of events ix67: 66.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 52.0 Number of missing values ix0: 0
# Number of events ix67: 72.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 57.0 Number of missing values ix0: 0
# Number of events ix67: 72.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 63.0 Number of missing values ix0: 0
# Number of events ix67: 66.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 66.0 Number of missing values ix0: 0
# Number of events ix67: 65.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 56.0 Number of missing values ix0: 0
# Number of events ix67: 70.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 44.0 Number of missing values ix0: 0
# Number of events ix67: 55.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 58.0 Number of missing values ix0: 0
# Number of events ix67: 49.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 53.0 Number of missing values ix0: 0
# Number of events ix67: 49.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 55.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 50.0 Number of missing values ix0: 0
# Number of events ix67: 52.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 39.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 49.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 53.0 Number of missing values ix0: 0
# Number of events ix67: 53.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 54.0 Number of missing values ix0: 0
# Number of events ix67: 51.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 42.0 Number of missing values ix0: 0
# Number of events ix67: 57.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# KIRC
# Number of patients in 0_33 group CD8B: 178
# -3.1230594589096885 -0.3829285633382899
#
# Number of patients in 67-100 group CD8B: 178
# 0.45187592303000856 2.1744476557687737
#
# Number of patients in 0_33 group CXCR6: 178
# -4.384645716382011 -0.3354296902706975
#
# Number of patients in 67-100 group CXCR6: 178
# 0.47996960859937565 2.4158867788482423
#
# Number of patients in 0_33 group CXCR3: 178
# -4.410588620391014 -0.3322226005208838
#
# Number of patients in 67-100 group CXCR3: 178
# 0.4015404534548301 2.329655297883329
#
# Number of patients in 0_33 group CXCR2: 178
# -3.0235936239315087 -0.378269908087828
#
# Number of patients in 67-100 group CXCR2: 178
# 0.402116910717589 4.688037612701721
#
# Number of patients in 0_33 group CCR5: 178
# -4.168581701745398 -0.3256292806306565
#
# Number of patients in 67-100 group CCR5: 178
# 0.4434555402482463 2.2849591520821972
#
# Number of patients in 0_33 group CCR10: 178
# -4.380003615842839 -0.36348663854990315
#
# Number of patients in 67-100 group CCR10: 178
# 0.44342076242401285 4.618570230367682
#
# Number of patients in 0_33 group IL12B: 178
# -1.8020665905924853 -0.45560334117035783
#
# Number of patients in 67-100 group IL12B: 178
# 0.41253642048133116 2.9980910648604255
#
# Number of patients in 0_33 group CXCL16: 178
# -3.2183701076117908 -0.3999404391433873
#
# Number of patients in 67-100 group CXCL16: 178
# 0.45400369768164367 2.2705622481197367
#
# Number of patients in 0_33 group NK cells: 178
# -3.256918076599333 -0.3055767757162421
#
# Number of patients in 67-100 group NK cells: 178
# 0.40518314357222573 2.368206281052977
#
# Number of patients in 0_33 group CD19: 178
# -1.4809529032276343 -0.5105271182772618
#
# Number of patients in 67-100 group CD19: 178
# 0.23644528547703772 4.568953322300179
#
# PFS:  CD8B
# Number of events ix0: 70.0 Number of missing values ix0: 0
# Number of events ix67: 80.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 63.0 Number of missing values ix0: 0
# Number of events ix67: 79.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 63.0 Number of missing values ix0: 0
# Number of events ix67: 87.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 83.0 Number of missing values ix0: 0
# Number of events ix67: 68.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 70.0 Number of missing values ix0: 0
# Number of events ix67: 74.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 65.0 Number of missing values ix0: 0
# Number of events ix67: 90.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 76.0 Number of missing values ix0: 0
# Number of events ix67: 71.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 72.0 Number of missing values ix0: 0
# Number of events ix67: 82.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 89.0 Number of missing values ix0: 0
# Number of events ix67: 67.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 67.0 Number of missing values ix0: 0
# Number of events ix67: 83.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 58.0 Number of missing values ix0: 0
# Number of events ix67: 68.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 48.0 Number of missing values ix0: 0
# Number of events ix67: 68.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 48.0 Number of missing values ix0: 0
# Number of events ix67: 76.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 66.0 Number of missing values ix0: 0
# Number of events ix67: 53.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 56.0 Number of missing values ix0: 0
# Number of events ix67: 66.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 44.0 Number of missing values ix0: 0
# Number of events ix67: 79.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 60.0 Number of missing values ix0: 0
# Number of events ix67: 60.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 55.0 Number of missing values ix0: 0
# Number of events ix67: 67.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 71.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 46.0 Number of missing values ix0: 0
# Number of events ix67: 69.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# BLCA
# Number of patients in 0_33 group CD8B: 136
# -2.6703110364636395 -0.40449224286772073
#
# Number of patients in 67-100 group CD8B: 136
# 0.39603818335114804 3.361467507383329
#
# Number of patients in 0_33 group CXCR6: 136
# -2.833671385682469 -0.4215719772036859
#
# Number of patients in 67-100 group CXCR6: 136
# 0.4393245982408574 2.6556128322490875
#
# Number of patients in 0_33 group CXCR3: 136
# -2.751364669017636 -0.4588301310403743
#
# Number of patients in 67-100 group CXCR3: 136
# 0.42809531153832664 2.4550393781437205
#
# Number of patients in 0_33 group CXCR2: 136
# -2.7137890209667983 -0.4944867224424607
#
# Number of patients in 67-100 group CXCR2: 136
# 0.4637327476644147 2.7786469656092363
#
# Number of patients in 0_33 group CCR5: 136
# -3.6289808367514267 -0.4585115211661863
#
# Number of patients in 67-100 group CCR5: 136
# 0.5226663998202964 2.4416541086960724
#
# Number of patients in 0_33 group CCR10: 136
# -2.2979156851626397 -0.4724966062505239
#
# Number of patients in 67-100 group CCR10: 136
# 0.3374732134489147 3.458131004170665
#
# Number of patients in 0_33 group IL12B: 136
# -1.236328564930262 -0.6137642832645307
#
# Number of patients in 67-100 group IL12B: 136
# 0.3714385982209177 3.370450599666582
#
# Number of patients in 0_33 group CXCL16: 136
# -4.099750802536314 -0.3754153766279661
#
# Number of patients in 67-100 group CXCL16: 136
# 0.4376552185763539 2.8682833152732194
#
# Number of patients in 0_33 group NK cells: 136
# -1.6863645622660006 -0.5022933489010677
#
# Number of patients in 67-100 group NK cells: 136
# 0.3358431486345217 2.6985201460728474
#
# Number of patients in 0_33 group CD19: 136
# -1.388626011752736 -0.6224550083492079
#
# Number of patients in 67-100 group CD19: 136
# 0.37048934682181406 3.387338266777727
#
# PFS:  CD8B
# Number of events ix0: 77.0 Number of missing values ix0: 0
# Number of events ix67: 74.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 78.0 Number of missing values ix0: 0
# Number of events ix67: 74.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 76.0 Number of missing values ix0: 0
# Number of events ix67: 72.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 79.0 Number of missing values ix0: 0
# Number of events ix67: 69.0 Number of missing values ix67: 0
# The ``p_value_threshold`` is set at 0.01. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 272 total observations, 124 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#          test_statistic    p  -log2(p)
# ix km              5.26 0.02      5.52
#    rank            5.92 0.01      6.06
# 1. Variable 'ix' failed the non-proportional test: p-value is 0.0149.
#
#    Advice: with so few unique values (only 2), you can include `strata=['ix', ...]` in the call in
# `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
# PFS:  CCR5
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 77.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 89.0 Number of missing values ix0: 0
# Number of events ix67: 79.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 76.0 Number of missing values ix0: 0
# Number of events ix67: 71.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 78.0 Number of missing values ix0: 0
# Number of events ix67: 84.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 85.0 Number of missing values ix0: 0
# Number of events ix67: 74.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 74.0 Number of missing values ix0: 0
# Number of events ix67: 79.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 60.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 63.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 60.0 Number of missing values ix0: 0
# Number of events ix67: 58.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 65.0 Number of missing values ix0: 0
# Number of events ix67: 46.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 58.0 Number of missing values ix0: 0
# Number of events ix67: 61.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 71.0 Number of missing values ix0: 0
# Number of events ix67: 67.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 57.0 Number of missing values ix0: 0
# Number of events ix67: 58.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 60.0 Number of missing values ix0: 0
# Number of events ix67: 65.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 56.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 56.0 Number of missing values ix0: 0
# Number of events ix67: 59.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# LIHC
# Number of patients in 0_33 group CD8B: 124
# -2.562240745172741 -0.4454036229687092
#
# Number of patients in 67-100 group CD8B: 124
# 0.28891938118310373 2.7425617747217323
#
# Number of patients in 0_33 group CXCR6: 124
# -3.625979736036324 -0.377589338672637
#
# Number of patients in 67-100 group CXCR6: 124
# 0.44210078469100517 2.6729020450644234
#
# Number of patients in 0_33 group CXCR3: 124
# -2.735993456602109 -0.43625119467811224
#
# Number of patients in 67-100 group CXCR3: 124
# 0.3968825765180518 2.7730913515607654
#
# Number of patients in 0_33 group CXCR2: 124
# -2.208629598140941 -0.4274737537906998
#
# Number of patients in 67-100 group CXCR2: 124
# 0.36896992876788304 3.658004443102418
#
# Number of patients in 0_33 group CCR5: 124
# -2.9979151101248456 -0.4332215102522103
#
# Number of patients in 67-100 group CCR5: 124
# 0.45181320512132067 2.7211139460612013
#
# Number of patients in 0_33 group CCR10: 124
# -2.9064382643793265 -0.3426228477658914
#
# Number of patients in 67-100 group CCR10: 124
# 0.24211664465007715 4.379764117219231
#
# Number of patients in 0_33 group IL12B: 124
# -1.3924803921077977 -0.7511291830651168
#
# Number of patients in 67-100 group IL12B: 124
# 0.4953981825035131 3.3770597930773496
#
# Number of patients in 0_33 group CXCL16: 124
# -2.6623628502162657 -0.4779689706864675
#
# Number of patients in 67-100 group CXCL16: 124
# 0.39765028842841876 2.8901049436299235
#
# Number of patients in 0_33 group NK cells: 124
# -1.9980928352011524 -0.43925211740244646
#
# Number of patients in 67-100 group NK cells: 124
# 0.3187947616160506 3.3752055994007515
#
# Number of patients in 0_33 group CD19: 124
# -1.3755790714137333 -0.6081346817298676
#
# Number of patients in 67-100 group CD19: 124
# 0.2999538166575207 3.645631113287685
#
# PFS:  CD8B
# Number of events ix0: 78.0 Number of missing values ix0: 0
# Number of events ix67: 66.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 84.0 Number of missing values ix0: 0
# Number of events ix67: 66.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 83.0 Number of missing values ix0: 0
# Number of events ix67: 68.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 73.0 Number of missing values ix0: 0
# Number of events ix67: 78.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 63.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 70.0 Number of missing values ix0: 0
# Number of events ix67: 80.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 75.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 69.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 86.0 Number of missing values ix0: 0
# Number of events ix67: 63.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 79.0 Number of missing values ix0: 0
# Number of events ix67: 72.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 45.0 Number of missing values ix0: 0
# Number of events ix67: 38.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 51.0 Number of missing values ix0: 0
# Number of events ix67: 33.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 50.0 Number of missing values ix0: 0
# Number of events ix67: 39.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 40.0 Number of missing values ix0: 0
# Number of events ix67: 43.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 46.0 Number of missing values ix0: 0
# Number of events ix67: 36.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 36.0 Number of missing values ix0: 0
# Number of events ix67: 52.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 46.0 Number of missing values ix0: 0
# Number of events ix67: 43.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 42.0 Number of missing values ix0: 0
# Number of events ix67: 41.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 47.0 Number of missing values ix0: 0
# Number of events ix67: 37.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 47.0 Number of missing values ix0: 0
# Number of events ix67: 41.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
#
#
#
#
# SKCM
# Number of patients in 0_33 group CD8B: 157
# -2.453374779921947 -0.4607645500019852
#
# Number of patients in 67-100 group CD8B: 157
# 0.5677229809390804 2.143254260416845
#
# Number of patients in 0_33 group CXCR6: 156
# -2.7124408245054377 -0.46599583814620577
#
# Number of patients in 67-100 group CXCR6: 157
# 0.4989105205610839 2.343921557909661
#
# Number of patients in 0_33 group CXCR3: 156
# -2.6965762807828453 -0.4482878365516078
#
# Number of patients in 67-100 group CXCR3: 157
# 0.5530201407299012 2.6260083418574407
#
# Number of patients in 0_33 group CXCR2: 156
# -1.8824648356842857 -0.48772638753170977
#
# Number of patients in 67-100 group CXCR2: 157
# 0.2757125325614847 3.2235985768883384
#
# Number of patients in 0_33 group CCR5: 156
# -3.07043344578503 -0.4634333001316263
#
# Number of patients in 67-100 group CCR5: 157
# 0.5382983364826226 2.501869422564624
#
# Number of patients in 0_33 group CCR10: 157
# -2.925670632901845 -0.47601038310044114
#
# Number of patients in 67-100 group CCR10: 157
# 0.37224977544551835 3.405480251936486
#
# Number of patients in 0_33 group IL12B: 156
# -1.3761014093578903 -0.6109816769305279
#
# Number of patients in 67-100 group IL12B: 157
# 0.41114519306894415 3.630767785033312
#
# Number of patients in 0_33 group CXCL16: 157
# -3.2083049839750126 -0.3585502344280273
#
# Number of patients in 67-100 group CXCL16: 157
# 0.48841599632772387 3.3601987882449484
#
# Number of patients in 0_33 group NK cells: 156
# -1.5977655019125967 -0.47479966309312704
#
# Number of patients in 67-100 group NK cells: 157
# 0.3562972722991786 2.479718688926681
#
# Number of patients in 0_33 group CD19: 157
# -1.3684170286193669 -0.6783899013169968
#
# Number of patients in 67-100 group CD19: 157
# 0.4988878205021246 2.6564689056904935
#
# PFS:  CD8B
# Number of events ix0: 118.0 Number of missing values ix0: 0
# Number of events ix67: 101.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR6
# Number of events ix0: 118.0 Number of missing values ix0: 0
# Number of events ix67: 103.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR3
# Number of events ix0: 119.0 Number of missing values ix0: 0
# Number of events ix67: 101.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCR2
# Number of events ix0: 119.0 Number of missing values ix0: 0
# Number of events ix67: 107.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR5
# Number of events ix0: 112.0 Number of missing values ix0: 0
# Number of events ix67: 108.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CCR10
# Number of events ix0: 111.0 Number of missing values ix0: 0
# Number of events ix67: 108.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  IL12B
# Number of events ix0: 113.0 Number of missing values ix0: 0
# Number of events ix67: 103.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CXCL16
# Number of events ix0: 110.0 Number of missing values ix0: 0
# Number of events ix67: 102.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  NK cells
# Number of events ix0: 110.0 Number of missing values ix0: 0
# Number of events ix67: 102.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# PFS:  CD19
# Number of events ix0: 113.0 Number of missing values ix0: 0
# Number of events ix67: 100.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD8B
# Number of events ix0: 92.0 Number of missing values ix0: 0
# Number of events ix67: 52.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR6
# Number of events ix0: 91.0 Number of missing values ix0: 0
# Number of events ix67: 50.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR3
# Number of events ix0: 88.0 Number of missing values ix0: 0
# Number of events ix67: 54.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCR2
# Number of events ix0: 79.0 Number of missing values ix0: 0
# Number of events ix67: 75.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR5
# Number of events ix0: 86.0 Number of missing values ix0: 0
# Number of events ix67: 54.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CCR10
# Number of events ix0: 77.0 Number of missing values ix0: 0
# Number of events ix67: 64.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  IL12B
# Number of events ix0: 83.0 Number of missing values ix0: 0
# Number of events ix67: 60.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CXCL16
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 61.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  NK cells
# Number of events ix0: 80.0 Number of missing values ix0: 0
# Number of events ix67: 58.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
# OS:  CD19
# Number of events ix0: 81.0 Number of missing values ix0: 0
# Number of events ix67: 52.0 Number of missing values ix67: 0
# Proportional hazard assumption looks okay.
